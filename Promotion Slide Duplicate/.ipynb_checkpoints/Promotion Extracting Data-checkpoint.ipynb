# %%
# %run "..\general_functions\generalFunctions.ipynb"
# %run "..\general_functions\Extracting Data Functions.ipynb"

# %% [markdown]
# #### Data Parameters

# %%
# f_name ="C:/Users/BW4SA/Desktop/Slide Automation/Mondelez Norway/Mondelez Norway Chocolate Dataset.xlsx"
f_name = "C:/Users/rapha/OneDrive/Desktop/Mondelez Norway/Mondelez Norway Chocolate Dataset.xlsx"
client_manuf = ["Mondelez"]
client_brands = ["Freia", "Twist", "Daim"]
currency = ' Kr'
decimals = 2
sign = "After"

categories = ["Chocolate"]
sectors = ["Tablet","Countlines/Bar","Small Bites","Pralines","Seasonal And Novelties"]
segments = ["Tablet Milk", "Tablet Dark","Countlines/Bar Milk", "Countlines/Bar Dark", "Small Bites Milk", "Small Bites Dark", "Pralines Mix", "Pralines Milk", "Pralines Dark", "Seasonal And Novelties Milk","Seasonal And Novelties Mix", "Seasonal And Novelties Dark"]
areas = ['NATIONAL', "RETAILER"]
POS = ""
prodORitem = 'Product'
regions = ["Extra", "Kiwi"]
channels = []
markets = []
 
normalized = True # Set False if we're not using Normalized Columns for Volume/Value Uplift

promo_col = [] # Guidline Promo Columns ex :Volume Uplift >>> "[Measures].[Volume Uplift IYA]" using filter_dictionary_keys(fieldsNamePosition, 'Volume Upli')
data_source = "DATA SOURCE: Consumer Test | May 2024 & Trade Panel/Retailer Data | Ending Jan 2024"
years = ['2021', '2022','2023']

# Add one month to the original ending date
end_date = "2024-02-01"

# %%
month_years =  pd.date_range(end=end_date , periods=12, freq='M').strftime('%b-%y').tolist()

# %%
f_path = Path.cwd()
excel = client.gencache.EnsureDispatch('Excel.Application')
excel.Visible = True  # False
wb = excel.Workbooks.Open(f_name)
ws=wb.Sheets([s.Name for s in wb.Sheets][0])
pvtTable = ws.PivotTables(1)


#change report layout
pvtTable.RowAxisLayout(1)   #RowAxisLayout(1) for tabular form

#change pivot table style
#Select from Design tab, try out Medium9 or Medium3
pvtTable.TableStyle2 = "pivotStyleMedium21"
pvtTable.ClearTable()

pvtTable.TableRange2.Cut(ws.Range("A13"))

fieldsNamePosition={}
for i in range(1,pvtTable.CubeFields.Count+1):
    fieldsNamePosition[str(pvtTable.CubeFields(i))]=i

# %%
start_time = time.time()

# %%
filter_dictionary_keys(fieldsNamePosition, 'Volume Upli')
# Out:
# {'[Measures].[Volume Uplift (v. Base)]': 647,
#  '[Measures].[Volume Uplift (v. Base) Normalized]': 773,
#  '[Measures].[Volume Uplift IYA]': 790,
#  '[Measures].[Volume Uplift Normalized IYA]': 791,
#  '[Measures].[Brand Volume Uplift (v. Base) ]': 804,
#  '[Measures].[Volume Uplift (v. Base) raw]': 1558,
#  '[Measures].[Volume Uplift (v. Base) Normalized raw]': 1559,
#  '[Measures].[Brand Volume Uplift (v. Base) raw]': 1570}

# %% [markdown]
# #### By Brands For P12M

# %%
promotions_brands_P12M = {}

# %%
row_list=['[Products].[Top Brands]', '[Products].[Total Size]']
column_list=[]
filter_list=['[Products].[Category]','[Scope].[Scope]', '[Calendar].[MonthYear]','[Market].[Area]','[Market].[Region]','[Market].[Channel]','[Market].[Market]','[Products].[Sector]','[Products].[Segment]']
if normalized == True:
    value_list=['[Measures].[Promo Value]', '[Measures].[VSOD]', '[Measures].[VSOD IYA]',  '[Measures].[Value Share]','[Measures].[Promo Share]', '[Measures].[Value Uplift (v. base) Normalized]', '[Measures].[Value Uplift Normalized IYA]','[Measures].[Volume Uplift (v. Base) Normalized]', '[Measures].[Volume Uplift Normalized IYA]'] + promo_col
else:
    value_list=['[Measures].[Promo Value]', '[Measures].[VSOD]', '[Measures].[VSOD IYA]',  '[Measures].[Value Share]','[Measures].[Promo Share]', '[Measures].[Value Uplift (v. base)]', '[Measures].[Value Uplift IYA]','[Measures].[Volume Uplift (v. Base)]', '[Measures].[Volume Uplift IYA]'] + promo_col
    
pvtTable.ClearTable()
pvtTable = set_excel_fields(row_list,column_list,filter_list,value_list,pvtTable)

pvtTable.PivotFields("[Products].[Category].[Category]").ClearAllFilters()
pvtTable.PivotFields('[Products].[Category].[Category]').CurrentPageName = f'[Products].[Category].&[{categories[0]}]'

pvtTable.PivotFields('[Calendar].[MonthYear].[MonthYear]').ClearAllFilters()
pvtTable.CubeFields('[Calendar].[MonthYear]').EnableMultiplePageItems = True 
visible_items = []
for value in month_years:
    visible_items.append(f"[Calendar].[MonthYear].&[{value}]")
pvtTable.PivotFields('[Calendar].[MonthYear].[MonthYear]').VisibleItemsList = visible_items

# %%
pvtTable.PivotFields("[Scope].[Scope].[Scope]").ClearAllFilters()
pvtTable.PivotFields('[Scope].[Scope].[Scope]').CurrentPageName = '[Scope].[Scope].&[Category]'

pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
pvtTable.PivotFields('[Market].[Area].[Area]').CurrentPageName = f'[Market].[Area].&[NATIONAL]'
wb.Save()
con = pd.read_excel(f_name, sheet_name=s_name)        
promotions_brands_P12M[f'{categories[0]} | National'] = con
pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()

if len(regions)!=0:
    promotions_brands_P12M = create_dataframe(regions,promotions_brands_P12M,"[Market].[Region].[Region]",pvtTable, f'{categories[0]} | ')
    pvtTable.PivotFields('[Market].[Region].[Region]').ClearAllFilters()
if len(channels)!=0:
    promotions_brands_P12M = create_dataframe(channels,promotions_brands_P12M,"[Market].[Channel].[Channel]",pvtTable, f'{categories[0]} | ')
    pvtTable.PivotFields('[Market].[Channel].[Channel]').ClearAllFilters()

if len(markets) !=0:
    promotions_brands_P12M = create_dataframe(markets,promotions_brands_P12M,"[Market].[Market].[Market]",pvtTable, f'{categories[0]} | ')
    pvtTable.PivotFields('[Market].[Market].[Market]').ClearAllFilters()



# By Sector



pvtTable.PivotFields("[Scope].[Scope].[Scope]").ClearAllFilters()
pvtTable.PivotFields('[Scope].[Scope].[Scope]').CurrentPageName = '[Scope].[Scope].&[Sector]'

pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
pvtTable.PivotFields('[Market].[Area].[Area]').CurrentPageName = f'[Market].[Area].&[NATIONAL]'


promotions_brands_P12M = create_dataframe(sectors,promotions_brands_P12M,'[Products].[Sector].[Sector]',pvtTable, 'National | ')
pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
pvtTable.PivotFields('[Products].[Sector].[Sector]').ClearAllFilters()


promotions_brands_P12M= create_dataframe(regions,promotions_brands_P12M,"[Market].[Region].[Region]",pvtTable, '',sectors,'[Products].[Sector].[Sector]' )
pvtTable.PivotFields("[Market].[Region].[Region]").ClearAllFilters()
pvtTable.PivotFields('[Products].[Sector].[Sector]').ClearAllFilters()

promotions_brands_P12M= create_dataframe(channels,promotions_brands_P12M,"[Market].[Channel].[Channel]",pvtTable, '',sectors,'[Products].[Sector].[Sector]' )
pvtTable.PivotFields("[Market].[Channel].[Channel]").ClearAllFilters()
pvtTable.PivotFields('[Products].[Sector].[Sector]').ClearAllFilters()

if len(markets)!=0 :
    promotions_brands_P12M= create_dataframe(markets,promotions_brands_P12M,"[Market].[Market].[Market]",pvtTable, '',sectors,'[Products].[Sector].[Sector]' )
    pvtTable.PivotFields("[Market].[Market].[Market]").ClearAllFilters()
    pvtTable.PivotFields('[Products].[Sector].[Sector]').ClearAllFilters()




# By Segments


if len(segments)!=0:
    pvtTable.PivotFields("[Scope].[Scope].[Scope]").ClearAllFilters()
    pvtTable.PivotFields('[Scope].[Scope].[Scope]').CurrentPageName = '[Scope].[Scope].&[Segment]'

    pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
    pvtTable.PivotFields('[Market].[Area].[Area]').CurrentPageName = f'[Market].[Area].&[NATIONAL]'
    
    
    promotions_brands_P12M = create_dataframe(segments,promotions_brands_P12M,'[Products].[Segment].[Segment]',pvtTable, 'National | ') 
    pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()

    
    promotions_brands_P12M= create_dataframe(regions,promotions_brands_P12M,"[Market].[Region].[Region]",pvtTable, '',segments,'[Products].[Segment].[Segment]' )
    pvtTable.PivotFields("[Market].[Region].[Region]").ClearAllFilters()
    pvtTable.PivotFields('[Products].[Segment].[Segment]').ClearAllFilters()

    promotions_brands_P12M= create_dataframe(channels,promotions_brands_P12M,"[Market].[Channel].[Channel]",pvtTable, '',segments,'[Products].[Segment].[Segment]' )
    pvtTable.PivotFields("[Market].[Channel].[Channel]").ClearAllFilters()
    pvtTable.PivotFields('[Products].[Segment].[Segment]').ClearAllFilters()

    if len(markets) !=0:
        promotions_brands_P12M= create_dataframe(markets,promotions_brands_P12M,"[Market].[Market].[Market]",pvtTable, '',segments,'[Products].[Segment].[Segment]' )
        pvtTable.PivotFields("[Market].[Market].[Market]").ClearAllFilters()
        pvtTable.PivotFields('[Products].[Segment].[Segment]').ClearAllFilters()

# %%
with open('promotions_brands_P12M.pickle', 'wb') as handle:
    pickle.dump(promotions_brands_P12M, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ###### VSOD

# %%
VSOD = {}

# %%
row_list=['[Products].[Sector]']
column_list=[]
filter_list=['[Products].[Category]','[Scope].[Scope]', '[Calendar].[MonthYear]','[Market].[Area]','[Market].[Region]','[Market].[Channel]','[Market].[Market]']
value_list=['[Measures].[VSOD]']

pvtTable.ClearTable()
pvtTable = set_excel_fields(row_list,column_list,filter_list,value_list,pvtTable)

pvtTable.PivotFields("[Products].[Category].[Category]").ClearAllFilters()
pvtTable.PivotFields('[Products].[Category].[Category]').CurrentPageName = f'[Products].[Category].&[{categories[0]}]'

pvtTable.PivotFields('[Calendar].[MonthYear].[MonthYear]').ClearAllFilters()
pvtTable.CubeFields('[Calendar].[MonthYear]').EnableMultiplePageItems = True 
visible_items = []
for value in month_years:
    visible_items.append(f"[Calendar].[MonthYear].&[{value}]")
pvtTable.PivotFields('[Calendar].[MonthYear].[MonthYear]').VisibleItemsList = visible_items

# %%
pvtTable.PivotFields("[Scope].[Scope].[Scope]").ClearAllFilters()
pvtTable.PivotFields('[Scope].[Scope].[Scope]').CurrentPageName = '[Scope].[Scope].&[Category]'

pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
pvtTable.PivotFields('[Market].[Area].[Area]').CurrentPageName = f'[Market].[Area].&[NATIONAL]'
wb.Save()
con = pd.read_excel(f_name, sheet_name=s_name)        
VSOD[f'{categories[0]} | National'] = con
pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()


VSOD = create_dataframe(regions,VSOD,"[Market].[Region].[Region]",pvtTable, f'{categories[0]} | ')
pvtTable.PivotFields('[Market].[Region].[Region]').ClearAllFilters()

if len(channels) !=0:
    VSOD = create_dataframe(channels,VSOD,"[Market].[Channel].[Channel]",pvtTable, f'{categories[0]} | ')
    pvtTable.PivotFields('[Market].[Channel].[Channel]').ClearAllFilters()

if len(markets) !=0:
    VSOD = create_dataframe(markets,VSOD,"[Market].[Market].[Market]",pvtTable, f'{categories[0]} | ')
    pvtTable.PivotFields('[Market].[Market].[Market]').ClearAllFilters()

# %%
with open('VSOD.pickle', 'wb') as handle:
    pickle.dump(VSOD, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
VSOD_Client = {}

# %%
row_list=['[Products].[Sector]']
column_list=['[Products].[Top Brands]']
filter_list=['[Products].[Category]','[Scope].[Scope]', '[Calendar].[MonthYear]','[Market].[Area]','[Market].[Region]','[Market].[Channel]','[Market].[Market]']
value_list=['[Measures].[VSOD]']

pvtTable.ClearTable()
pvtTable = set_excel_fields(row_list,column_list,filter_list,value_list,pvtTable)

pvtTable.PivotFields("[Products].[Category].[Category]").ClearAllFilters()
pvtTable.PivotFields('[Products].[Category].[Category]').CurrentPageName = f'[Products].[Category].&[{categories[0]}]'

pvtTable.PivotFields('[Calendar].[MonthYear].[MonthYear]').ClearAllFilters()
pvtTable.CubeFields('[Calendar].[MonthYear]').EnableMultiplePageItems = True 
visible_items = []
for value in month_years:
    visible_items.append(f"[Calendar].[MonthYear].&[{value}]")
pvtTable.PivotFields('[Calendar].[MonthYear].[MonthYear]').VisibleItemsList = visible_items 



pvtTable.PivotFields('[Products].[Top Brands].[Top Brands]').ClearAllFilters()
pvtTable.CubeFields('[Products].[Top Brands]').EnableMultiplePageItems = True 
visible_items = []
for value in client_brands:
    visible_items.append(f"[Products].[Top Brands].&[{value}]")
pvtTable.PivotFields('[Products].[Top Brands].[Top Brands]').VisibleItemsList = visible_items

# %%
pvtTable.PivotFields("[Scope].[Scope].[Scope]").ClearAllFilters()
pvtTable.PivotFields('[Scope].[Scope].[Scope]').CurrentPageName = '[Scope].[Scope].&[Category]'

pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
pvtTable.PivotFields('[Market].[Area].[Area]').CurrentPageName = f'[Market].[Area].&[NATIONAL]'
wb.Save()
con = pd.read_excel(f_name, sheet_name=s_name)        
VSOD_Client[f'{categories[0]} | National'] = con
pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()


VSOD_Client = create_dataframe(regions,VSOD_Client,"[Market].[Region].[Region]",pvtTable, f'{categories[0]} | ')
pvtTable.PivotFields('[Market].[Region].[Region]').ClearAllFilters()

if len(channels) !=0:
    VSOD_Client = create_dataframe(channels,VSOD_Client,"[Market].[Channel].[Channel]",pvtTable, f'{categories[0]} | ')
    pvtTable.PivotFields('[Market].[Channel].[Channel]').ClearAllFilters()

if len(markets) !=0:
    VSOD_Client = create_dataframe(markets,VSOD_Client,"[Market].[Market].[Market]",pvtTable, f'{categories[0]} | ')
    pvtTable.PivotFields('[Market].[Market].[Market]').ClearAllFilters()

# %%
with open('VSOD_Client.pickle', 'wb') as handle:
    pickle.dump(VSOD_Client, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# #### By Products/Item P12M

# %%
promotions_products_P12M = {}

# %%
row_list=['[Products].[Top Brands]', f'[Products].[{prodORitem}]']
column_list=[]
filter_list=['[Products].[Category]','[Scope].[Scope]', '[Calendar].[MonthYear]','[Market].[Area]','[Market].[Region]','[Market].[Channel]','[Market].[Market]','[Products].[Sector]','[Products].[Segment]']
value_list=['[Measures].[Promo Sales]', '[Measures].[Promo Value]','[Measures].[Discount Depth (%)]', '[Measures].[Promo Share]','[Measures].[VSOD]','[Measures].[Base Price/Unit]','[Measures].[Promo Price/Unit]','[Measures].[Gross Margin %]','[Measures].[Value Uplift (v. base) Normalized]', '[Measures].[Volume Uplift (v. Base) Normalized]','[Measures].[Trade Effectiveness]','[Measures].[Incr Value]']

pvtTable.ClearTable()
pvtTable = set_excel_fields(row_list,column_list,filter_list,value_list,pvtTable)

pvtTable.PivotFields("[Products].[Category].[Category]").ClearAllFilters()
pvtTable.PivotFields('[Products].[Category].[Category]').CurrentPageName = f'[Products].[Category].&[{categories[0]}]'

pvtTable.PivotFields('[Calendar].[MonthYear].[MonthYear]').ClearAllFilters()
pvtTable.CubeFields('[Calendar].[MonthYear]').EnableMultiplePageItems = True 
visible_items = []
for value in month_years:
    visible_items.append(f"[Calendar].[MonthYear].&[{value}]")
pvtTable.PivotFields('[Calendar].[MonthYear].[MonthYear]').VisibleItemsList = visible_items

# %%
pvtTable.PivotFields("[Scope].[Scope].[Scope]").ClearAllFilters()
pvtTable.PivotFields('[Scope].[Scope].[Scope]').CurrentPageName = '[Scope].[Scope].&[Category]'

pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
pvtTable.PivotFields('[Market].[Area].[Area]').CurrentPageName = f'[Market].[Area].&[NATIONAL]'
wb.Save()
con = pd.read_excel(f_name, sheet_name=s_name)        
promotions_products_P12M[f'{categories[0]} | National'] = con
pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()


promotions_products_P12M = create_dataframe(regions,promotions_products_P12M,"[Market].[Region].[Region]",pvtTable, f'{categories[0]} | ')
pvtTable.PivotFields('[Market].[Region].[Region]').ClearAllFilters()

promotions_products_P12M = create_dataframe(channels,promotions_products_P12M,"[Market].[Channel].[Channel]",pvtTable, f'{categories[0]} | ')
pvtTable.PivotFields('[Market].[Channel].[Channel]').ClearAllFilters()

if len(markets) !=0:
    promotions_products_P12M = create_dataframe(markets,promotions_products_P12M,"[Market].[Market].[Market]",pvtTable, f'{categories[0]} | ')
    pvtTable.PivotFields('[Market].[Market].[Market]').ClearAllFilters()

# By Sector

pvtTable.PivotFields("[Scope].[Scope].[Scope]").ClearAllFilters()
pvtTable.PivotFields('[Scope].[Scope].[Scope]').CurrentPageName = '[Scope].[Scope].&[Sector]'

pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
pvtTable.PivotFields('[Market].[Area].[Area]').CurrentPageName = f'[Market].[Area].&[NATIONAL]'


promotions_products_P12M = create_dataframe(sectors,promotions_products_P12M,'[Products].[Sector].[Sector]',pvtTable, 'National | ')
pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
pvtTable.PivotFields('[Products].[Sector].[Sector]').ClearAllFilters()


promotions_products_P12M= create_dataframe(regions,promotions_products_P12M,"[Market].[Region].[Region]",pvtTable, '',sectors,'[Products].[Sector].[Sector]' )
pvtTable.PivotFields("[Market].[Region].[Region]").ClearAllFilters()
pvtTable.PivotFields('[Products].[Sector].[Sector]').ClearAllFilters()

promotions_products_P12M= create_dataframe(channels,promotions_products_P12M,"[Market].[Channel].[Channel]",pvtTable, '',sectors,'[Products].[Sector].[Sector]' )
pvtTable.PivotFields("[Market].[Channel].[Channel]").ClearAllFilters()
pvtTable.PivotFields('[Products].[Sector].[Sector]').ClearAllFilters()

if len(markets)!=0 :
    promotions_products_P12M= create_dataframe(markets,promotions_products_P12M,"[Market].[Market].[Market]",pvtTable, '',sectors,'[Products].[Sector].[Sector]' )
    pvtTable.PivotFields("[Market].[Market].[Market]").ClearAllFilters()
    pvtTable.PivotFields('[Products].[Sector].[Sector]').ClearAllFilters()

# By Segments

if len(segments)!=0:
    pvtTable.PivotFields("[Scope].[Scope].[Scope]").ClearAllFilters()
    pvtTable.PivotFields('[Scope].[Scope].[Scope]').CurrentPageName = '[Scope].[Scope].&[Segment]'

    pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
    pvtTable.PivotFields('[Market].[Area].[Area]').CurrentPageName = f'[Market].[Area].&[NATIONAL]'
    
    
    promotions_products_P12M = create_dataframe(segments,promotions_products_P12M,'[Products].[Segment].[Segment]',pvtTable, 'National | ') 
    pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()

    
    promotions_products_P12M= create_dataframe(regions,promotions_products_P12M,"[Market].[Region].[Region]",pvtTable, '',segments,'[Products].[Segment].[Segment]' )
    pvtTable.PivotFields("[Market].[Region].[Region]").ClearAllFilters()
    pvtTable.PivotFields('[Products].[Segment].[Segment]').ClearAllFilters()

    promotions_products_P12M= create_dataframe(channels,promotions_products_P12M,"[Market].[Channel].[Channel]",pvtTable, '',segments,'[Products].[Segment].[Segment]' )
    pvtTable.PivotFields("[Market].[Channel].[Channel]").ClearAllFilters()
    pvtTable.PivotFields('[Products].[Segment].[Segment]').ClearAllFilters()

    if len(markets) !=0:
        promotions_products_P12M= create_dataframe(markets,promotions_products_P12M,"[Market].[Market].[Market]",pvtTable, '',segments,'[Products].[Segment].[Segment]' )
        pvtTable.PivotFields("[Market].[Market].[Market]").ClearAllFilters()
        pvtTable.PivotFields('[Products].[Segment].[Segment]').ClearAllFilters()

# %%
with open('promotions_products_P12M.pickle', 'wb') as handle:
    pickle.dump(promotions_products_P12M, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### By End of The Week

# %%
promotions_EndOfWeek = {}

# %%
row_list=['[Calendar].[End of Week]']
column_list=[]
filter_list=['[Products].[Category]','[Scope].[Scope]','[Market].[Area]','[Market].[Region]','[Market].[Channel]','[Market].[Market]','[Products].[Top Brands]','[Products].[Sector]','[Products].[Segment]']
value_list=['[Measures].[Promo Value]','[Measures].[Non-Promo Value]','[Measures].[Value Sales]','[Measures].[Base Sales]','[Measures].[VSOD]','[Measures].[Promo Volume]','[Measures].[Non-Promo Volume]']

pvtTable.ClearTable()
pvtTable = set_excel_fields(row_list,column_list,filter_list,value_list,pvtTable)

pvtTable.PivotFields("[Products].[Category].[Category]").ClearAllFilters()
pvtTable.PivotFields('[Products].[Category].[Category]').CurrentPageName = f'[Products].[Category].&[{categories[0]}]'

# %%
for brand in client_brands:
    pvtTable.PivotFields("[Products].[Top Brands].[Top Brands]").ClearAllFilters()
    pvtTable.PivotFields('[Products].[Top Brands].[Top Brands]').CurrentPageName = f'[Products].[Top Brands].&[{brand}]'

    
    pvtTable.PivotFields("[Scope].[Scope].[Scope]").ClearAllFilters()
    pvtTable.PivotFields('[Scope].[Scope].[Scope]').CurrentPageName = '[Scope].[Scope].&[Category]'
    
    pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
    pvtTable.PivotFields('[Market].[Area].[Area]').CurrentPageName = f'[Market].[Area].&[NATIONAL]'
    wb.Save()
    con = pd.read_excel(f_name, sheet_name=s_name)        
    promotions_EndOfWeek[f'{categories[0]} | {brand} | National'] = con
    pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
    
    
    promotions_EndOfWeek = create_dataframe(regions,promotions_EndOfWeek,"[Market].[Region].[Region]",pvtTable, f'{categories[0]} | {brand} | ')
    pvtTable.PivotFields('[Market].[Region].[Region]').ClearAllFilters()
    
    promotions_EndOfWeek = create_dataframe(channels,promotions_EndOfWeek,"[Market].[Channel].[Channel]",pvtTable, f'{categories[0]} | {brand} | ')
    pvtTable.PivotFields('[Market].[Channel].[Channel]').ClearAllFilters()
    
    if len(markets) !=0:
        promotions_EndOfWeek = create_dataframe(markets,promotions_EndOfWeek,"[Market].[Market].[Market]",pvtTable, f'{categories[0]} | {brand} | ')
        pvtTable.PivotFields('[Market].[Market].[Market]').ClearAllFilters()
    
    
    
    # By Sector
    
    
    
    pvtTable.PivotFields("[Scope].[Scope].[Scope]").ClearAllFilters()
    pvtTable.PivotFields('[Scope].[Scope].[Scope]').CurrentPageName = '[Scope].[Scope].&[Sector]'
    
    pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
    pvtTable.PivotFields('[Market].[Area].[Area]').CurrentPageName = f'[Market].[Area].&[NATIONAL]'
    
    
    promotions_EndOfWeek = create_dataframe(sectors,promotions_EndOfWeek,'[Products].[Sector].[Sector]',pvtTable, f'{brand} | National | ')
    pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
    pvtTable.PivotFields('[Products].[Sector].[Sector]').ClearAllFilters()
    
    
    promotions_EndOfWeek= create_dataframe(regions,promotions_EndOfWeek,"[Market].[Region].[Region]",pvtTable, f'{brand} | ',sectors,'[Products].[Sector].[Sector]')
    pvtTable.PivotFields("[Market].[Region].[Region]").ClearAllFilters()
    pvtTable.PivotFields('[Products].[Sector].[Sector]').ClearAllFilters()
    
    promotions_EndOfWeek= create_dataframe(channels,promotions_EndOfWeek,"[Market].[Channel].[Channel]",pvtTable, f'{brand} | ',sectors,'[Products].[Sector].[Sector]' )
    pvtTable.PivotFields("[Market].[Channel].[Channel]").ClearAllFilters()
    pvtTable.PivotFields('[Products].[Sector].[Sector]').ClearAllFilters()
    
    if len(markets)!=0 :
        promotions_EndOfWeek= create_dataframe(markets,promotions_EndOfWeek,"[Market].[Market].[Market]",pvtTable, f'{brand} | ',sectors,'[Products].[Sector].[Sector]' )
        pvtTable.PivotFields("[Market].[Market].[Market]").ClearAllFilters()
        pvtTable.PivotFields('[Products].[Sector].[Sector]').ClearAllFilters()
        
    
    # By Segments
    
    
    if len(segments)!=0:
        pvtTable.PivotFields("[Scope].[Scope].[Scope]").ClearAllFilters()
        pvtTable.PivotFields('[Scope].[Scope].[Scope]').CurrentPageName = '[Scope].[Scope].&[Segment]'
    
        pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
        pvtTable.PivotFields('[Market].[Area].[Area]').CurrentPageName = f'[Market].[Area].&[NATIONAL]'
        
        
        promotions_EndOfWeek = create_dataframe(segments,promotions_EndOfWeek,'[Products].[Segment].[Segment]',pvtTable, f'{brand} | National | ') 
        pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
    
        
        promotions_EndOfWeek= create_dataframe(regions,promotions_EndOfWeek,"[Market].[Region].[Region]",pvtTable, f'{brand} | ',segments,'[Products].[Segment].[Segment]' )
        pvtTable.PivotFields("[Market].[Region].[Region]").ClearAllFilters()
        pvtTable.PivotFields('[Products].[Segment].[Segment]').ClearAllFilters()
    
        promotions_EndOfWeek= create_dataframe(channels,promotions_EndOfWeek,"[Market].[Channel].[Channel]",pvtTable, f'{brand} | ',segments,'[Products].[Segment].[Segment]' )
        pvtTable.PivotFields("[Market].[Channel].[Channel]").ClearAllFilters()
        pvtTable.PivotFields('[Products].[Segment].[Segment]').ClearAllFilters()
    
        if len(markets) !=0:
            promotions_EndOfWeek= create_dataframe(markets,promotions_EndOfWeek,"[Market].[Market].[Market]",pvtTable, f'{brand} | ',segments,'[Products].[Segment].[Segment]' )
            pvtTable.PivotFields("[Market].[Market].[Market]").ClearAllFilters()
            pvtTable.PivotFields('[Products].[Segment].[Segment]').ClearAllFilters()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3928\4060016017.py in <module>
#      11     wb.Save()
#      12     con = pd.read_excel(f_name, sheet_name=s_name)
# ---> 13     promotions_EndOfWeek[f'{categories[0]} | {brand} | National'] = con
#      14     pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
#      15
#
# NameError: name 'promotions_EndOfWeek' is not defined

# %%
with open('promotions_EndOfWeek.pickle', 'wb') as handle:
    pickle.dump(promotions_EndOfWeek, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# #### Value Uplift vs Discount depth

# %%
value_uplift = {}

# %%
row_list=[]
column_list=[]
filter_list=['[Products].[Category]','[Scope].[Scope]','[Market].[Area]','[Market].[Region]','[Market].[Channel]','[Market].[Market]','[Products].[Top Brands]','[Products].[Sector]','[Products].[Segment]']
value_list=[]

pvtTable.ClearTable()
pvtTable = set_excel_fields(row_list,column_list,filter_list,value_list,pvtTable)

pvtTable.PivotFields("[Products].[Category].[Category]").ClearAllFilters()
pvtTable.PivotFields('[Products].[Category].[Category]').CurrentPageName = f'[Products].[Category].&[{categories[0]}]'

row_list = ['[Products].[Product]','[Calendar].[End of Week]']
value_list = ['[Measures].[Discount Depth (%)]','[Measures].[Promo Price/Unit]', '[Measures].[Value Uplift (v. base) Normalized]','[Measures].[Promo Sales]']

pvtTable = set_excel_fields(row_list,column_list,filter_list,value_list,pvtTable)

# %%
for brand in client_brands:
    pvtTable.PivotFields("[Products].[Top Brands].[Top Brands]").ClearAllFilters()
    pvtTable.PivotFields('[Products].[Top Brands].[Top Brands]').CurrentPageName = f'[Products].[Top Brands].&[{brand}]'

    
    pvtTable.PivotFields("[Scope].[Scope].[Scope]").ClearAllFilters()
    pvtTable.PivotFields('[Scope].[Scope].[Scope]').CurrentPageName = '[Scope].[Scope].&[Category]'
    
    pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
    pvtTable.PivotFields('[Market].[Area].[Area]').CurrentPageName = f'[Market].[Area].&[NATIONAL]'
    wb.Save()
    con = pd.read_excel(f_name, sheet_name=s_name)        
    value_uplift[f'{categories[0]} | {brand} | National'] = con
    pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
    
    
    value_uplift = create_dataframe(regions,value_uplift,"[Market].[Region].[Region]",pvtTable, f'{categories[0]} | {brand} | ')
    pvtTable.PivotFields('[Market].[Region].[Region]').ClearAllFilters()
    
    value_uplift = create_dataframe(channels,value_uplift,"[Market].[Channel].[Channel]",pvtTable, f'{categories[0]} | {brand} | ')
    pvtTable.PivotFields('[Market].[Channel].[Channel]').ClearAllFilters()
    
    if len(markets) !=0:
        value_uplift = create_dataframe(markets,value_uplift,"[Market].[Market].[Market]",pvtTable, f'{categories[0]} | {brand} | ')
        pvtTable.PivotFields('[Market].[Market].[Market]').ClearAllFilters()
    
    
    
    # By Sector
    
    
    
    pvtTable.PivotFields("[Scope].[Scope].[Scope]").ClearAllFilters()
    pvtTable.PivotFields('[Scope].[Scope].[Scope]').CurrentPageName = '[Scope].[Scope].&[Sector]'
    
    pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
    pvtTable.PivotFields('[Market].[Area].[Area]').CurrentPageName = f'[Market].[Area].&[NATIONAL]'
    
    
    value_uplift = create_dataframe(sectors,value_uplift,'[Products].[Sector].[Sector]',pvtTable, f'{brand} | National | ')
    pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
    pvtTable.PivotFields('[Products].[Sector].[Sector]').ClearAllFilters()
    
    
    value_uplift= create_dataframe(regions,value_uplift,"[Market].[Region].[Region]",pvtTable, f'{brand} | ',sectors,'[Products].[Sector].[Sector]')
    pvtTable.PivotFields("[Market].[Region].[Region]").ClearAllFilters()
    pvtTable.PivotFields('[Products].[Sector].[Sector]').ClearAllFilters()
    
    value_uplift= create_dataframe(channels,value_uplift,"[Market].[Channel].[Channel]",pvtTable, f'{brand} | ',sectors,'[Products].[Sector].[Sector]' )
    pvtTable.PivotFields("[Market].[Channel].[Channel]").ClearAllFilters()
    pvtTable.PivotFields('[Products].[Sector].[Sector]').ClearAllFilters()
    
    if len(markets)!=0 :
        value_uplift= create_dataframe(markets,value_uplift,"[Market].[Market].[Market]",pvtTable, f'{brand} | ',sectors,'[Products].[Sector].[Sector]' )
        pvtTable.PivotFields("[Market].[Market].[Market]").ClearAllFilters()
        pvtTable.PivotFields('[Products].[Sector].[Sector]').ClearAllFilters()
    
    
    
    
    # By Segments
    
    
    if len(segments)!=0:
        pvtTable.PivotFields("[Scope].[Scope].[Scope]").ClearAllFilters()
        pvtTable.PivotFields('[Scope].[Scope].[Scope]').CurrentPageName = '[Scope].[Scope].&[Segment]'
    
        pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
        pvtTable.PivotFields('[Market].[Area].[Area]').CurrentPageName = f'[Market].[Area].&[NATIONAL]'
        
        
        value_uplift = create_dataframe(segments,value_uplift,'[Products].[Segment].[Segment]',pvtTable, f'{brand} | National | ') 
        pvtTable.PivotFields('[Market].[Area].[Area]').ClearAllFilters()
    
        
        value_uplift= create_dataframe(regions,value_uplift,"[Market].[Region].[Region]",pvtTable, f'{brand} | ',segments,'[Products].[Segment].[Segment]' )
        pvtTable.PivotFields("[Market].[Region].[Region]").ClearAllFilters()
        pvtTable.PivotFields('[Products].[Segment].[Segment]').ClearAllFilters()
    
        value_uplift= create_dataframe(channels,value_uplift,"[Market].[Channel].[Channel]",pvtTable, f'{brand} | ',segments,'[Products].[Segment].[Segment]' )
        pvtTable.PivotFields("[Market].[Channel].[Channel]").ClearAllFilters()
        pvtTable.PivotFields('[Products].[Segment].[Segment]').ClearAllFilters()
    
        if len(markets) !=0:
            value_uplift= create_dataframe(markets,value_uplift,"[Market].[Market].[Market]",pvtTable, f'{brand} | ',segments,'[Products].[Segment].[Segment]' )
            pvtTable.PivotFields("[Market].[Market].[Market]").ClearAllFilters()
            pvtTable.PivotFields('[Products].[Segment].[Segment]').ClearAllFilters()

# %%
with open('value_uplift.pickle', 'wb') as handle:
    pickle.dump(value_uplift, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
end_time = time.time()

elapsed_time = end_time - start_time
print(f"Script started at: {time.ctime(start_time)}")
print(f"Script ended at: {time.ctime(end_time)}")
print(f"Elapsed time: {elapsed_time:.2f} seconds")
# Out:
# Script started at: Sun May 12 09:29:41 2024
# Script ended at: Sun May 12 10:02:15 2024
# Elapsed time: 1954.65 seconds
