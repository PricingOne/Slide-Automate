# %%
# %run "..\general_functions\generalFunctions.ipynb"
# %run "..\Landscape slide duplicate\Landscape Replacement Function.ipynb"

# %%
start_time = time.time()

# %%
themePath = r"C:\\Users\\BW4SA\\OneDrive - Pricing One SA\\Desktop\\Theme1.thmx"

# %% [markdown]
# ## Data Parameters

# %%
client_manuf = ["Edgewell"]
client_brands = ["Xtreme 3","Extra 3","Hydro","Quattro Titanium","Classic","Quattro","Extra 2","Duplo"]
decimals = 2
sign = "After"
currency = '€'
currency = ' '+ currency if sign.lower() == 'after' else  currency + ' ' 
percent = 100000
percentstr="'00 000"

categories = ["Male Shaving"]
sectors = ["Disposable","System"]
segments = ["Lame","Rasoi"]
subsegments= ["Rasoi No Sensitive", "Rasoi Sensitive", "Disposable No Sensitive","Disposable Sensitive"]
subcategories= ["1 Blades",	"2 Blades",	"3 Blades",	"4 Blades",	"5 Blades"]

national = True
customareas= "DRUGSTORES"
areas = ['NATIONAL', "RETAILER","CHANNEL",customareas]#, "CHANNEL"

regions_RET  = ["Cesar"]
channels_RET = []
market_RET = []

retMarketLength = 3-((not regions_RET)+(not channels_RET)+(not market_RET))

regions_CHAN = []
channels_CHAN = ["Drugstores", "Hyper", "Super", "Discount", "Liberi Servizi"]#"Discount","Hm/Sm","Small Format"
market_CHAN = []
chanMarketLength = 3-((not regions_CHAN)+(not channels_CHAN)+(not market_CHAN))

regions_CUST = []
channels_CUST = ["Drugstores Area 1","Drugstores Area 2","Drugstores Area 3","Drugstores Area 4"]
market_CUST = []
custMarketLength = 3-((not regions_CUST)+(not channels_CUST)+(not market_CUST))

data_source = "DATA SOURCE: Trade Panel/Retailer Data | Ending Feb 2024"
years = ['2021', '2022','2023']


catg_hier = {"SubCategory":{"Segment":"Sector"}, 
             "SubSegment" : {"Segment":"Sector"}}

direct_parent = {"Sector":list(zip(["Category"]*len(categories),categories)),
                "Segment":list(zip(["Sector"]*len(sectors),sectors)),
                "SubSegment":list(zip(["Segment"]*len(segments),segments)), 
                "SubCategory":list(zip(["Segment"]*len(segments),segments))}

# %%
retailer = regions_RET + channels_RET + market_RET
channel  = regions_CHAN + channels_CHAN + market_CHAN
custom = regions_CUST + channels_CUST + market_CUST

# %% [markdown]
# ### Cleaning Data_frames

# %% [markdown]
# ### Modifying Dataframes

# %%
loaded_data = {}

datasets_path = os.getcwd()+"/Landscape Datasets/"
print(datasets_path)

datasets = os.listdir(datasets_path)
for d in datasets:
    with open(datasets_path+d, 'rb') as handle:
        globals()[d.split('.')[0]] = pd.read_pickle(handle)
# Out:
# C:\Users\khaled\PowePoint Automation\Slide-Automate\Landscape slide duplicate/Landscape Datasets/

# %% [markdown]
# ### Slide 12 : Category Evolution Analysis  Cleaning

# %%
def cleanSectorSegemnt(dfDic):
    catDic,totalDic = {},{}
    for key,df in dfDic.items():
        df=df.copy()
        catIndex = df.index[df['Unnamed: 0'].isin(['Sector','Segment','SubSegment','SubCategory'])][0]
        catName = df['Unnamed: 0'][catIndex]
        df.columns = (df.iloc[catIndex].replace(np.nan,'') + ' '+df.iloc[catIndex-1].ffill().replace(np.nan, "")).str.replace(' Values','').str.strip()#.str.replace('Total ','')
        df = df.iloc[catIndex+1:]
        df[catName] = df[catName].ffill()
        
        df = df.applymap(lambda x: float(x) if pd.to_numeric(x, errors='coerce') == x else x)
        df = df.applymap(lambda x: 0 if pd.isna(x) else x)
#         print(key,df.columns)
        addative = df[~df[catName].str.contains(' Total')].sort_values('WoB %', ascending = False)
        
        total = df[df[catName].str.contains(' Total')]
        total[catName] = total[catName].str.replace(' Total','')

        catDic[key.replace('  ',' ')] = addative
        totalDic[key.replace('  ',' ')] = total
        
    return catDic,totalDic

# %%
cea_sector_P12M_new,cea_dya_sector_new,cea_sector_clients_new,cea_sector_clients_total_new ={},{},{},{}

if sectors:
    cea_sectors_P12M_new,cea_dya_sectors_new=cleanSectorSegemnt(sectors_P12M_dfs)
    cea_sectors_clients_new,cea_sectors_clients_total_new=cleanSectorSegemnt(sectors_client_dfs)

cea_segment_P12M_new,cea_dya_segment_new,cea_segment_clients_new,cea_segment_clients_total_new ={},{},{},{}

if segments:
    cea_segment_P12M_new,cea_dya_segment_new=cleanSectorSegemnt(segments_P12M_dfs)
    cea_segment_clients_new,cea_segment_clients_total_new=cleanSectorSegemnt(segments_client_dfs)

# %%
cea_subsegment_P12M_new,cea_dya_subsegment_new,cea_subsegment_clients_new,cea_subsegment_clients_total_new ={},{},{},{}
if subsegments:
    cea_subsegment_P12M_new,cea_dya_subsegment_new=cleanSectorSegemnt(subsegments_P12M_dfs_new)
    cea_subsegment_clients_new,cea_subsegment_clients_total_new=cleanSectorSegemnt(subsegments_client_dfs_new)

cea_subcategory_P12M_new,cea_dya_subcategory_new,cea_subcategory_clients_new,cea_subcategory_clients_total_new ={},{},{},{}
if subcategories:
    cea_subcategory_P12M_new,cea_dya_subcategory_new=cleanSectorSegemnt(subcategories_P12M_dfs_new)
    cea_subcategory_clients_new,cea_subcategory_clients_total_new=cleanSectorSegemnt(subcategories_client_dfs_new)

# %% [markdown]
# ## Slide 13 : Share And Growth

# %%
def marketSplit(retailersDic,retailerList,channelList,custList):
    market_regions,market_channels,market_markets = {},{},{}
#     channels_regions,channels_channels,channels_markets = {},{},{}   
#     cust_regions,cust_channels,cust_markets             = {},{},{}        
    total_area = {}
    
    for key,value in retailersDic.items():
        
        table = value.copy()
        table.columns = table.iloc[12]
        table = table.iloc[table[table[table.columns[0]]==table.columns[0]].index[0]+1:]
        table=table.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
        table.columns = table.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
        table['Value Share'] = table['Value Share'].astype(float)
        table = table.sort_values('WoB %', ascending=False)
        gran_tot = table[table['Region'] == "Grand Total"]


        table['Channel'] = np.where(table['Channel'].isna(), table['Region'], table['Channel'])
        table['Market'] = np.where(table['Market'].isna(), table['Channel'], table['Market'])
        table['Region'] = table['Region'].ffill()

        regionDf = table[(table['Region'].str.contains('Total'))]
        regionDf = regionDf[regionDf.Region.str.replace('Total','').str.strip().isin(retailerList)].drop(columns = ['Channel', 'Market'])
        regionDf['Region'] = regionDf['Region'].str.replace('Total', '').str.strip()

        regionDf = regionDf.drop_duplicates()

        channelDf = table[table['Channel'].str.replace('Total', '').str.strip().isin(channelList)].drop(columns = ['Region','Market'])
        channelDf['Channel'] = channelDf['Channel'].str.replace(' Total', '')

        channelDf = channelDf.drop_duplicates()

        marketDf = table[table['Channel'].isin(custList)].drop(columns = ['Region','Channel'])

        marketDf = marketDf.drop_duplicates()

        if not regionDf.empty:
            market_regions[key] = pd.concat([gran_tot,regionDf])
        if not channelDf.empty:   
            market_channels[key] =  pd.concat([gran_tot,channelDf])
        if not marketDf.empty:
            market_markets[key] =  pd.concat([gran_tot,marketDf])
        if not gran_tot.empty:    
            total_area[key] = gran_tot
    return market_regions,market_channels,market_markets,total_area

# %%
retailerRegion,retailerChannel,retailertMarket,retailerTotal=marketSplit(retailers_dfs_new,regions_RET,channels_RET,market_RET)
channelRegion,channelChannel,channelMarket,custTotal=marketSplit(channel_dfs_new,regions_CHAN,channels_CHAN,market_CHAN)
custRegion,custChannel,custMarket,custTotal=marketSplit(cust_dfs_new,regions_CUST,channels_CUST,market_CUST)

# %%
clientRetailerRegion,clientretailerChannel,clientRetailertMarket,retailerClientTotal=marketSplit(retailers_client_dfs_new,regions_RET,channels_RET,market_RET)
clientChannelRegion,clientChannelChannel,clientChannelMarket,custClientTotal=marketSplit(channel_client_dfs_new,regions_CHAN,channels_CHAN,market_CHAN)
clientCustRegion,clientCustChannel,clientCustMarket,custClientTotal=marketSplit(cust_client_dfs_new,regions_CUST,channels_CUST,market_CUST)

# %%
retailerCatDic,retailerSecDic,retailerSegDic,retailerSubSegDic,retailerSubCatDic=[],[],[],[],[]
cahnnelCatDic,cahnnelSecDic,cahnnelSegDic,cahnnelSubSegDic,cahnnelSubCatDic=[],[],[],[],[]
custCatDic,custSecDic,custSegDic,custSubSegDic,custSubCatDic=[],[],[],[],[]

if retailers_dfs_new:

    retailerCatDic = [key for key in retailerClientTotal.keys() if (len(set(categories).intersection(set(key.split(' | '))))) ]
    retailerSecDic = [key for key in retailerClientTotal.keys() if len(set(sectors).intersection(set(key.split(' | '))))]
    retailerSegDic = [key for key in retailerClientTotal.keys() if len(set(segments).intersection(set(key.split(' | '))))]
    retailerSubSegDic = [key for key in retailerClientTotal.keys() if len(set(subsegments).intersection(set(key.split(' | '))))]
    retailerSubCatDic = [key for key in retailerClientTotal.keys() if len(set(subcategories).intersection(set(key.split(' | '))))]



if channel_dfs_new:

    channelCatDic = [key for key in custClientTotal.keys() if len(set(categories).intersection(set(key.split(' | '))))]
    channelSecDic = [key for key in custClientTotal.keys() if len(set(sectors).intersection(set(key.split(' | '))))]
    channelSegDic = [key for key in custClientTotal.keys() if len(set(segments).intersection(set(key.split(' | '))))]
    channelSubSegDic = [key for key in custClientTotal.keys() if len(set(subsegments).intersection(set(key.split(' | '))))]
    channelSubCatDic = [key for key in custClientTotal.keys() if len(set(subcategories).intersection(set(key.split(' | '))))]

if cust_dfs_new:
#     modified_cust,cust_total=cleaningMarket(cust_dfs_new)
#     modified_cust_clients,cust_clients_total=cleaningMarket(cust_client_dfs_new)
    custCatDic = [key for key in custClientTotal.keys() if len(set(categories).intersection(set(key.split(' | ')))) ]
    custSecDic = [key for key in custClientTotal.keys() if len(set(sectors).intersection(set(key.split(' | ')))) ]
    custSegDic = [key for key in custClientTotal.keys() if len(set(segments).intersection(set(key.split(' | '))))]
    custSubSegDic = [key for key in custClientTotal.keys() if len(set(subsegments).intersection(set(key.split(' | '))))]
    custSubCatDic = [key for key in custClientTotal.keys() if len(set(subcategories).intersection(set(key.split(' | '))))]

# %%
retailerField = {'Region':[retailerRegion,clientRetailerRegion],'Channel':[retailerChannel,clientretailerChannel],'Market':[retailertMarket,clientRetailertMarket]}
channelField = {'Region':[channelRegion,clientChannelRegion],'Channel':[channelChannel,clientChannelChannel],'Market':[channelMarket,clientChannelMarket]}
custField = {'Region':[custRegion,clientCustRegion],'Channel':[custChannel,clientCustChannel],'Market':[custMarket,clientCustMarket]}

# %% [markdown]
# ## Slide Creations

# %%
def genrateIndexList(scopeCategory ,chartIndex =0 ,chartCount =4 ):
    if len(scopeCategory) == 0:
        return []
    page = len(scopeCategory) # number of sector or segment or category
 
    lis=[]
    while page >chartCount:
        lis.append(chartCount + chartIndex)
        page -=chartCount
    lis.append(page + chartIndex)
    return [lis]

sectorIndex = genrateIndexList(sectors,4,3)
segmentIndex = genrateIndexList(segments,4,3)

# %%
len(retailerSecDic)
# Out:
# 12

# %%
# retailerDup = [len(retailerCatDic.keys()),len(retailerSecDic.keys()),len(retailerSegDic.keys())] if retailers_dfs_new else[]
# channelDup = [len(channelCatDic.keys()),len(channelSecDic.keys()),len(channelSegDic.keys())] if channel_dfs_new else[]
# custDup = [len(custCatDic.keys()),len(custSecDic.keys()),len(custSegDic.keys())] if cust_dfs_new else[]
retailerDup = [len(retailerCatDic)*retMarketLength,len(retailerSecDic)*retMarketLength,len(retailerSegDic)*retMarketLength,len(retailerSubSegDic)*retMarketLength,len(retailerSubCatDic)*retMarketLength] 
channelDup = [len(channelCatDic)*chanMarketLength,len(channelSecDic)*chanMarketLength,len(channelSegDic)*chanMarketLength,len(channelSubSegDic)*chanMarketLength,len(channelSubCatDic)*chanMarketLength] 
custDup = [len(custCatDic)*custMarketLength,len(custSecDic)*custMarketLength,len(custSegDic)*custMarketLength,len(custSubSegDic)*custMarketLength,len(custSubCatDic)*custMarketLength]

# %%
custSubCatDic
# Out:
# ['Edgewell | 1 Blades',
#  'Edgewell | 2 Blades',
#  'Edgewell | 3 Blades',
#  'Edgewell | 4 Blades',
#  'Edgewell | 5 Blades',
#  'Xtreme 3 | 3 Blades',
#  'Extra 3 | 3 Blades',
#  'Hydro | 3 Blades',
#  'Hydro | 5 Blades',
#  'Quattro Titanium | 4 Blades',
#  'Classic | 2 Blades',
#  'Quattro | 4 Blades',
#  'Extra 2 | 2 Blades',
#  'Duplo | 2 Blades']

# %%
slide13Index=[*[12]* (((5 -(not sectors) + (not segments) + (not subsegments)+ (not subcategories) )) *(9 - ((not regions_RET)+(not channels_RET) + (not market_RET)+ (not regions_CHAN)+ (not channels_CHAN)+ (not market_CHAN)+ (not regions_CUST)+ (not channels_CUST)+ (not market_CUST))  ))]

slide13Dup = retailerDup + channelDup + custDup
index = [*[11]*4 ]+slide13Index

duplication = [len(cea_sectors_clients_new.keys()),len(cea_segment_clients_new.keys())*len(sectors),len(cea_subsegment_clients_new.keys())*len(segments),len(cea_subcategory_clients_new.keys())*len(segments)] + slide13Dup 

section_names_slide11 =  ["Sales and Growth By Sector"]+(["Sales and Growth By Segment"] if len(segments)>0 else [])+(["Sales and Growth By SubSegment"] if len(subsegments)>0 else [])+(["Sales and Growth By SubCategories"] if len(subcategories)>0 else [])

retailerSection = ["Share and Growth By Category By Retailer","Share and Growth By Sector By Retailer"]+["Share and Growth By Segment By Retailer"] +["Share and Growth By SubSegment By Retailer"] +["Share and Growth By SubCategory By Retailer"] 
channelSection = ["Share and Growth By Category By Channel","Share and Growth By Sector By Channel"]+["Share and Growth By Segment By Channel"]+["Share and Growth By SubSegment By Channel"] +["Share and Growth By SubCategory By Channel"] 
custSection = ["Share and Growth By Category By Region Channel","Share and Growth By Sector By Region Region Channel"]+["Share and Growth By Segment By Region Channel"]+["Share and Growth By SubSegment By Region Channel"] +["Share and Growth By SubCategory By Region Channel"] 
section_names_slide13 =  retailerSection+(channelSection if channel_client_dfs_new else [])+(custSection if cust_client_dfs_new else [])

section_names = [*section_names_slide11,*section_names_slide13]

# %%
path = os.getcwd() + '\Landscape base.pptx'
new_pre = os.getcwd() + '\Landscape duplicate.pptx'

# %%
print(len(index))
print(len(duplication))
print(len(section_names))
# Out:
# 19
# 19
# 19

# %%
slideDuplication(index,duplication,section_names,path,new_pre)

# %%
def calculate_position(end):
    return sum(duplication[i] * (1 if isinstance(index[i], int) else len(index[i])) for i in range(end))

# %% [markdown]
# ## Slide 12 : Category Evolution Analysis

# %%
# def categoryEvolution(prs,dictionaryOfClientDf,dictionaryOfTotalDf,TotalCat,TotalSec,brandOrManufacturerList,col='Sector',position = 0):
#     for slidenum,key in enumerate(dictionaryOfClientDf.keys()):
# #         print(key)
#         tablColDic = {2:'Value Sales IYA',3:'Volume Sales IYA',5:'IYA Price/KG',7:'Value Sales IYA',8:'Volume Sales IYA',10:'IYA Price/KG'}
#         shapes = prs.slides[slidenum+position].shapes
#         tables, charts = createTableAndChart(shapes)
#         title = shapes.title.text
# #         print( list(set(key.split(' | ')).intersection(set(brandOrManufacturerList))),set(key.split(' | ')),brandOrManufacturerList)
#         brandOrManufacturer = list(set(key.split(' | ')).intersection(set(brandOrManufacturerList)))[0]
#         dfClient = dictionaryOfClientDf[key].reset_index(drop=True)
#         keyTotal = key.replace(' | '+brandOrManufacturer,'')#.replace(' | ','')
        
#         header_num = get_shape_number(shapes,"Category Evolution Analysis")
#         title_num = get_shape_number(shapes,"Sales and Growth By Sector | National | P12M")
#         # print(title_num)
#         data_source_num = get_shape_number(shapes,"DATA SOURCE: Trade Panel/Retailer Data | Ending Sep 2022")
#         # print(data_source_num)
#         shapes[data_source_num].text = data_source
#         shapes[title_num].text = shapes[title_num].text.replace('Sector',col).replace('National',keyTotal.split(' | ')[1])
#         shapes[title_num].text_frame.paragraphs[0].font.size = Pt(12)
#         shapes[title_num].text_frame.paragraphs[0].font.name = 'Nexa Bold'
#         shapes[header_num].text_frame.paragraphs[0].font.size = Pt(16)
#         shapes[header_num].text_frame.paragraphs[0].font.name = 'Nexa Bold'
#         dfTotal =  dictionaryOfTotalDf[keyTotal].reset_index(drop=True)
# #         col = 'Sector'
#         missingSector=list(set(dfTotal[f"{col}"].unique())-set(dfClient[f"{col}"].unique()))
#         missingSector=pd.DataFrame({f"{col}":missingSector})
#         dfSectorTotal=pd.concat([dfClient,missingSector]).replace(np.nan,0).reset_index(drop=True)#.sort_values(by='Size' , ascending = False)
#         dfTotal = pd.concat([TotalCat[keyTotal],dfTotal]).reset_index(drop=True)
       

#         dfSectorTotal = pd.concat([TotalSec[key],dfSectorTotal]).reset_index(drop=True)
        
       
#         dfSectorTotal = dfSectorTotal.merge(dfTotal.reset_index()[['index',col]]).sort_values(by='index').drop(columns='index').reset_index(drop=True)

#         table=tables[1].table
#         num_rows_to_remove = len(table.rows)-dfTotal.shape[0]-2
#         table=removeRowFromTable(table,num_rows_to_remove,2)
    
#         for i, row in enumerate(table.rows):
#             for j, cell in enumerate(row.cells):
#                 if i == 0 and j == 6:
#                     cell.text = brandOrManufacturer
#                     cell.text_frame.paragraphs[0].font.name = 'Nexa Bold'
#                     cell.text_frame.paragraphs[0].font.size = Pt(8)
#                     cell.text_frame.paragraphs[0].alignment = PP_ALIGN.CENTER
#                     cell.text_frame.paragraphs[0].font.color.rgb = RGBColor(87, 85, 85) 
                    
#                 elif i in [0,1]:
#                     if i == 1 and j in [1,6]:
#                         cell.text = cell.text.replace('(M)',percentstr)
#                         cell.text_frame.paragraphs[0].font.name = 'Nexa Bold'
#                         cell.text_frame.paragraphs[0].font.size = Pt(8)
#                         cell.text_frame.paragraphs[0].alignment = PP_ALIGN.CENTER
#                         cell.text_frame.paragraphs[0].font.color.rgb = RGBColor(87, 85, 85) 

#                     pass
                
#                 elif j == 0:
#                     if i ==2:
#                         cell.text = 'Total'#cat if cat!='' else 'Sector'
#                     else:
#                         cell.text = dfTotal[col][i-2]
#                         cell.text_frame.paragraphs[0].font.name = 'Nexa Bold'
#                         cell.text_frame.paragraphs[0].font.size = Pt(8)


#                     cell.text_frame.paragraphs[0].font.name = 'Nexa Bold'
#                     cell.text_frame.paragraphs[0].font.size = Pt(8)

#                 elif j == 4: #Total Av Price/Vol
                   
#                     value =format_number(dfTotal['Av Price/KG'][i-2], use_decimals=True, decimals=2, use_apostrophes=False, currency_symbol=currency.strip(), currency_before=True if sign.lower=='before' else False)
#                     value = '' if float(value.split(' ')[0])==0 else value

#                     cell.text = value.replace(' ','')
#                 elif j == 9: # Av Price/Vol
                   
#                     value =format_number(dfSectorTotal['Av Price/KG'][i-2], use_decimals=True, decimals=2, use_apostrophes=False, currency_symbol=currency.strip(), currency_before=True if sign.lower=='before' else False)
#                     value = '' if float(value.split(' ')[0])==0 else value
#                     cell.text = value.replace(' ','')

#                 if j in [2,3,4,5,7,8,9,10] and i>=2:
#                     if j in [2,3,5]:
#                         value =  int(round(float(dfTotal[tablColDic[j]][i-2])*100,0))
                       
                    
#                     elif j in [7,8,10]:
#                         value =  int(round(float(dfSectorTotal[tablColDic[j]][i-2])*100,0))
#                     if j not in [4,9]:

#                         colorIndex = 90 if value <= 90 else 98 if value<=98 else 102 if (value >=102 and value < 110) else 110 if value >=110 else 0
#                         colorIndex = colorRule[colorIndex]
#                         value = '' if value==0 else value
#                         cell.text = str(value)
#                     cell.text_frame.paragraphs[0].font.size = Pt(8)
#                     cell.text_frame.paragraphs[0].alignment = PP_ALIGN.CENTER
#                     cell.text_frame.paragraphs[0].font.color.rgb = RGBColor(87,85,85) if j in [4,9] else colorIndex  #RGBColor(178,223,220)
#                     cell.text_frame.paragraphs[0].font.name = 'Nexa Book'
#         for i,df in enumerate([dfTotal,dfSectorTotal]):

#             chartTotal = charts[i].chart
#             chart_data = CategoryChartData()
#             chart_data.categories = df[col].to_list()
#             series = chart_data.add_series('Value Sales', df['Value Sales']/percent)
#             chartTotal.replace_data(chart_data)
#             for j, point in enumerate(chartTotal.series[0].points):
#                 data_label = point.data_label
#                 data_label.has_text_frame = True
# #                 value = format_number(series.values[j]/10**6, use_decimals=False, decimals=0, use_apostrophes=False, currency_symbol=currency, currency_before=True if sign.lower=='before' else False)
#                 value = format_number(df['Value Sales'][j]/percent, use_decimals=False, decimals=0, use_apostrophes=False, currency_symbol=currency, currency_before=True if sign.lower=='before' else False)
# #                 print(value,df['Value Sales'][j]/10**6)
# #                 value = '' if value.split(' ')[0]=='0' else value
# #                 print(value,'after')
#                 data_label.text_frame.text = value.replace(' ','').replace(',','')
#     #             data_label.text_frame.paragraphs[0].runs[0].font.color.rgb = RGBColor(255, 255, 255)
#                 data_label.text_frame.paragraphs[0].font.name = 'Nexa Book (Body)'
#                 data_label.text_frame.paragraphs[0].font.size = Pt(8)

# %%
prs = Presentation(new_pre)

# %%
p = 0
manuf_brand_list = client_manuf + client_brands

# %%
if sectors:

    categoryEvolution(prs,cea_sectors_clients_new,cea_sectors_P12M_new,cea_dya_sectors_new,cea_sectors_clients_total_new,manuf_brand_list,col="Sector",position = calculate_position(p))

    p+=1

# %%
# pos = len(modified_sectors_clients_new.keys())
if len(segments)!=0:
    posadd=calculate_position(p)
    for sec in sectors:
        categoryEvolution(prs,cea_segment_clients_new,cea_segment_P12M_new,cea_dya_segment_new,cea_segment_clients_total_new,manuf_brand_list,col='Segment',position = posadd)
        posadd += len(cea_segment_clients_new.keys())
    p+=1

# %%
# pos = len(modified_sectors_clients_new.keys())
if len(subsegments)!=0:
    posadd=calculate_position(p)
    for sec in segments:
        categoryEvolution(prs,cea_subsegment_clients_new,cea_subsegment_P12M_new,cea_dya_subsegment_new,cea_subsegment_clients_total_new,manuf_brand_list,col='SubSegment',position = posadd)
        posadd += len(cea_subsegment_clients_new.keys())
    p+=1

# %%
# pos = len(modified_sectors_clients_new.keys())
if len(subcategories)!=0:
    posadd=calculate_position(p)
    for sec in segments:
        categoryEvolution(prs,cea_subcategory_clients_new,cea_subcategory_P12M_new,cea_dya_subcategory_new,cea_subcategory_clients_total_new,manuf_brand_list,col='SubCategory',position = posadd)
        posadd += len(cea_subcategory_clients_new.keys())
    p+=1

# %%
sum(duplication[:4])
# Out:
# 693

# %% [markdown]
# ## Slide 13 : Share And Growth

# %%
# def shareGrowth(prs,dictionaryOfTotalClientDf,dictionaryOfTotalRetailer,catSecSeg,col='Region',retailType='Retailer',position = 0):
#     for slidenum,key in enumerate(dictionaryOfTotalClientDf.keys()):
#         shapes = prs.slides[slidenum+position].shapes
#         tables, charts = createTableAndChart(shapes)
# #         print(key,slidenum,len(dictionaryOfTotalClientDf))
#         cat = list(set(key.split(' | ')).intersection(set(catSecSeg)))[0]
#         catType = 'Category' if cat in categories else 'Sector' if cat in sectors else 'Segment' if cat in segments else 'SubSegmet' if cat in subsegments else 'SubCategory' 
        
#         market = list(set(key.split(' | '))-set([cat]))[0]
#         dfClient = dictionaryOfTotalClientDf[key].reset_index(drop=True)
#         dfTotal = dictionaryOfTotalRetailer[cat].reset_index(drop=True)
# #         dfTotal.iloc[0]['Channel'],dfTotal.iloc[0]['Region'],dfTotal.iloc[0]['MArket']='Total','Total','Total'
        
#         missingRegion=list(set(dfTotal[f"{col}"].unique())-set(dfClient[f"{col}"].unique()))
#         missingRegion=pd.DataFrame({f"{col}":missingRegion})
#         dfClient=pd.concat([dfClient,missingRegion]).replace(np.nan,0).reset_index(drop=True)
# #         dfClient.iloc[0]['Channel'],dfClient.iloc[0]['Region'],dfClient.iloc[0]['MArket']='Total','Total','Total'
        
        
#         title_num = get_shape_number(shapes,"Share and Growth By Retailer | Total Category | P12M")
#         data_source_num = get_shape_number(shapes,"DATA SOURCE: Trade Panel/Retailer Data | Ending Sep 2022")
#         shapes[data_source_num].text = data_source
#         shapes[title_num].text = shapes[title_num].text.replace('Category',catType).replace('Retailer',retailType)
#         shapes[title_num].text_frame.paragraphs[0].font.size = Pt(12)
#         shapes[title_num].text_frame.paragraphs[0].font.name = 'Nexa Bold'
#         shapes[title_num+1].text_frame.paragraphs[0].font.size = Pt(16)
#         shapes[title_num+1].text_frame.paragraphs[0].font.name = 'Nexa Bold'
# #         print(cat,'----',market,'----',key)
#         totalTable=tables[1].table
#         num_rows_to_remove = len(totalTable.rows)-dfTotal.shape[0]-2
# #         print(dfTotal.shape[0],num_rows_to_remove)
        
#         totalTable=removeRowFromTable(totalTable,num_rows_to_remove,2)
    
#         for i, row in enumerate(totalTable.rows):
#             for j, cell in enumerate(row.cells):
# #                 print('row: ',i,' Col: ',j,' Text: ',cell.text)
#                 if i == 0 and j == 1:
#                     cell.text = cat
#                     cell.text_frame.paragraphs[0].font.name = 'Nexa Bold'
#                     cell.text_frame.paragraphs[0].font.size = Pt(8)
#                     cell.text_frame.paragraphs[0].alignment = PP_ALIGN.CENTER
#                     cell.text_frame.paragraphs[0].font.color.rgb = RGBColor(87, 85, 85) 
                    
#                 elif i in [0,1]:
#                     if i==1 and j == 1:
#                         cell.text = cell.text.replace('(M)',percentstr)
#                         cell.text_frame.paragraphs[0].font.name = 'Nexa Bold'
#                         cell.text_frame.paragraphs[0].font.size = Pt(8)
#                         cell.text_frame.paragraphs[0].alignment = PP_ALIGN.CENTER
#                         cell.text_frame.paragraphs[0].font.color.rgb = RGBColor(87, 85, 85) 
                        
#                     pass
#                 elif j == 0:
#                     if i ==2:
#                         cell.text ='Total'# cat if cat!='' else 'Sector'
                        
#                     else:
#                         cell.text = dfTotal[col][i-2].replace(' Total','')
#                     cell.text_frame.paragraphs[0].font.name = 'Nexa Bold'
#                     cell.text_frame.paragraphs[0].font.size = Pt(8)
#                 elif j ==4:
# #                     value = int(round(dfTotal['Av Price/KG'][i-2],0))
# #                     value = '' if value == 0 else value
#                     value =format_number(dfTotal['Av Price/KG'][i-2], use_decimals=True, decimals=2, use_apostrophes=False, currency_symbol=currency.strip(), currency_before=True if sign.lower=='before' else False)
#                     value = '' if float(value.split(' ')[0])==0 else value

#                     cell.text = value
#                     cell.text_frame.paragraphs[0].font.name = 'Nexa Book'
#                     cell.text_frame.paragraphs[0].font.size = Pt(8)
#                     cell.text_frame.paragraphs[0].alignment = PP_ALIGN.CENTER
                    
#                 elif j ==5:
#                     value =  dfTotal['IYA Price/KG'][i-2]*100
                        
#                     colorIndex = 90 if value <= 90 else 98 if value<=98 else 102 if (value >=102 and value < 110) else 110 if value >=110 else 0
#                     colorIndex = colorRule[colorIndex]
#                     value =format_number(dfTotal['IYA Price/KG'][i-2]*100, use_decimals=True, decimals=2, use_apostrophes=False, currency_symbol=currency.strip(), currency_before=True if sign.lower=='before' else False)
#                     value = '' if float(value.split(' ')[0])==0 else value
#                     cell.text = value

# #                     value = '' if value==0 else value
# #                     cell.text = str(value)
#                     cell.text_frame.paragraphs[0].font.size = Pt(8)
#                     cell.text_frame.paragraphs[0].alignment = PP_ALIGN.CENTER
#                     cell.text_frame.paragraphs[0].font.color.rgb = colorIndex  #RGBColor(178,223,220)
#                     cell.text_frame.paragraphs[0].font.name = 'Nexa Book'

                
#         clientTable=tables[2].table
# #         print(num_rows_to_remove,'client')
#         clientTable=removeRowFromTable(clientTable,num_rows_to_remove,2)
    
#         for i, row in enumerate(clientTable.rows):
#             for j, cell in enumerate(row.cells):
# #                 print('row: ',i,' Col: ',j,' Text: ',cell.text)
#                 if i == 0 and j == 0:
#                     cell.text = market
#                     cell.text_frame.paragraphs[0].font.name = 'Nexa Bold'
#                     cell.text_frame.paragraphs[0].font.size = Pt(8)
#                     cell.text_frame.paragraphs[0].alignment = PP_ALIGN.CENTER
#                     cell.text_frame.paragraphs[0].font.color.rgb = RGBColor(87, 85, 85) 
                  
                    
#                 elif i in [0,1]:
#                     if i ==1 and j==0:
#                         cell.text = cell.text.replace('(M)',percentstr)
#                         cell.text_frame.paragraphs[0].font.name = 'Nexa Bold'
#                         cell.text_frame.paragraphs[0].font.size = Pt(8)
#                         cell.text_frame.paragraphs[0].alignment = PP_ALIGN.CENTER
#                         cell.text_frame.paragraphs[0].font.color.rgb = RGBColor(87, 85, 85) 
#                     pass
                
#                 elif j ==3:
# #                     value = int(round(dfClient['Av Price/KG'][i-2],0))
# #                     value = '' if value ==0 else value
# #                     print(dfClient['Av Price/KG'],i)
#                     value =format_number(dfClient['Av Price/KG'][i-2], use_decimals=True, decimals=2, use_apostrophes=False, currency_symbol=currency.strip(), currency_before=True if sign.lower=='before' else False)
#                     value = '' if float(value.split(' ')[0])==0 else value

#                     cell.text = value
#                     cell.text_frame.paragraphs[0].font.name = 'Nexa Book'
#                     cell.text_frame.paragraphs[0].font.size = Pt(8)
#                     cell.text_frame.paragraphs[0].alignment = PP_ALIGN.CENTER
#                 elif j ==4:
#                     value =  float(dfClient['IYA Price/KG'][i-2])*100
                    
#                     colorIndex = 90 if value <= 90 else 98 if value<=98 else 102 if (value >=102 and value < 110) else 110 if value >=110 else 0
#                     colorIndex = colorRule[colorIndex]
# #                     value = '' if value==0 else value
#                     value =format_number(dfClient['IYA Price/KG'][i-2]*100, use_decimals=True, decimals=2, use_apostrophes=False, currency_symbol=currency.strip(), currency_before=True if sign.lower=='before' else False)
#                     value = '' if float(value.split(' ')[0])==0 else value
                    
#                     cell.text = value
# #                     cell.text = str(value)
#                     cell.text_frame.paragraphs[0].font.size = Pt(8)
#                     cell.text_frame.paragraphs[0].alignment = PP_ALIGN.CENTER
#                     cell.text_frame.paragraphs[0].font.color.rgb = colorIndex  #RGBColor(178,223,220)
#                     cell.text_frame.paragraphs[0].font.name = 'Nexa Book'

                    
                    
                    
#         total = {0:'Trade WoB %',3:'Trade WoB % DYA',4:'Value Sales'}
#         client = {1:'Trade WoB %',2:'Trade WoB % DYA',5:'Value Sales'}
#         for key,value in total.items():
#             chartTotal = charts[key].chart

#             chart_data = CategoryChartData()
#             chart_data.categories = dfTotal[col].replace(np.nan,'Total').replace('Grand ','').to_list()
# #             print(dfTotal[col].replace('Grand ','').to_list())
#             series = chart_data.add_series(value, dfTotal[value.replace('Trade ','')])
# #             print(dfTotal)
#             chartTotal.replace_data(chart_data)
#             if key == 4 :

#                 for j, point in enumerate(chartTotal.series[0].points):
#                     data_label = point.data_label
#                     data_label.has_text_frame = True
#                     value = format_number(series.values[j]/percent, use_decimals=False, decimals=0, use_apostrophes=False, currency_symbol=currency, currency_before=True if sign.lower=='before' else False)
# #                     value = '' if value.split(' ')[0]=='0' else value
#                     data_label.text_frame.text = value.replace(' ','').replace(',','')
#         #             data_label.text_frame.paragraphs[0].runs[0].font.color.rgb = RGBColor(255, 255, 255)
#                     data_label.text_frame.paragraphs[0].font.name = 'Nexa Book'
#                     data_label.text_frame.paragraphs[0].font.size = Pt(8)
#                     data_label.position = XL_LABEL_POSITION.CENTER
        
#         for key,value in client.items():
#             chartClient = charts[key].chart

#             chart_data2 = CategoryChartData()
#             chart_data2.categories = dfClient[col].replace(0,'Total').replace(np.nan,'Total').replace('Grand ','').to_list()

#             series = chart_data2.add_series(value, dfClient[value.replace('Trade ','')])
#             chartClient.replace_data(chart_data2)
#             if key == 5 :

#                 for j, point in enumerate(chartClient.series[0].points):
#                     data_label = point.data_label
#                     data_label.has_text_frame = True
#                     value = format_number(series.values[j]/percent, use_decimals=False, decimals=0, use_apostrophes=False, currency_symbol=currency, currency_before=True if sign.lower=='before' else False)
#     #                 value = '' if value.split(' ')[0]=='0' else value
#                     data_label.text_frame.text = value.replace(' ','').replace(',','')
#         #             data_label.text_frame.paragraphs[0].runs[0].font.color.rgb = RGBColor(255, 255, 255)
#                     data_label.text_frame.paragraphs[0].font.name = 'Nexa Book'
#                     data_label.text_frame.paragraphs[0].font.size = Pt(8)
#                     data_label.position = XL_LABEL_POSITION.CENTER

# %%
catSecSeg=categories + sectors + segments + subsegments + subcategories
# p=4

# %%
if retailers_dfs_new:
    for key,val in retailerField.items():

        if categories and val[0]:
            clientDic = {key : val[1][key] for key in val[1].keys() if key in retailerCatDic}
            totalDic = {key : val[0][key] for key in val[0].keys() if key in categories}
            shareGrowth(prs,clientDic,totalDic,catSecSeg,col=key,position = calculate_position(p)) 
            p+=1
    for key,val in custField.items():

        if sectors and val[0]:   
            clientDic = {key : val[1][key] for key in val[1].keys() if key in retailerSecDic}
            totalDic = {key : val[0][key] for key in val[0].keys() if key in sectors}

            shareGrowth(prs,clientDic,totalDic,catSecSeg,col=key,position = calculate_position(p)) 
            p+=1

    for key,val in custField.items():

        if segments and val[0]: 
            clientDic = {key : val[1][key] for key in val[1].keys() if key in retailerSegDic}
            totalDic = {key : val[0][key] for key in val[0].keys() if key in segments}

            shareGrowth(prs,clientDic,totalDic,catSecSeg,col='Channel',position = calculate_position(p)) 
            p+=1
    for key,val in custField.items():

        if subsegments and val[0]:
            clientDic = {key : val[1][key] for key in val[1].keys() if key in retailerSubSegDic}
            totalDic = {key : val[0][key] for key in val[0].keys() if key in subsegments}

            shareGrowth(prs,clientDic,totalDic,catSecSeg,col=key,position = calculate_position(p)) 
            p+=1

            
    for key,val in custField.items():

        if subcategories and val[0]:
            clientDic = {key : val[1][key] for key in val[1].keys() if key in retailerSubCatDic}
            totalDic = {key : val[0][key] for key in val[0].keys() if key in subcategories}

            shareGrowth(prs,clientDic,totalDic,catSecSeg,col=key,position = calculate_position(p)) 
            p+=1

# %%
if channel_dfs_new:
    for key,val in channelField.items():

        if categories and val[0]:
            clientDic = {key : val[1][key] for key in val[1].keys() if key in channelCatDic}
            totalDic = {key : val[0][key] for key in val[0].keys() if key in categories}

            shareGrowth(prs,clientDic,totalDic,catSecSeg,col=key,position = calculate_position(p)) 
            p+=1
    for key,val in custField.items():

        if sectors and val[0]:   
            clientDic = {key : val[1][key] for key in val[1].keys() if key in channelSecDic}
            totalDic = {key : val[0][key] for key in val[0].keys() if key in sectors}

            shareGrowth(prs,clientDic,totalDic,catSecSeg,col=key,position = calculate_position(p)) 
            p+=1

    for key,val in custField.items():

        if segments and val[0]: 
            clientDic = {key : val[1][key] for key in val[1].keys() if key in channelSegDic}
            totalDic = {key : val[0][key] for key in val[0].keys() if key in segments}

            shareGrowth(prs,clientDic,totalDic,catSecSeg,col='Channel',position = calculate_position(p)) 
            p+=1
    for key,val in custField.items():

        if subsegments and val[0]:
            clientDic = {key : val[1][key] for key in val[1].keys() if key in channelSubSegDic}
            totalDic = {key : val[0][key] for key in val[0].keys() if key in subsegments}

            shareGrowth(prs,clientDic,totalDic,catSecSeg,col=key,position = calculate_position(p)) 
            p+=1

            
    for key,val in custField.items():

        if subcategories and val[0]:
            clientDic = {key : val[1][key] for key in val[1].keys() if key in channelSubCatDic}
            totalDic = {key : val[0][key] for key in val[0].keys() if key in subcategories}

            shareGrowth(prs,clientDic,totalDic,catSecSeg,col=key,position = calculate_position(p)) 
            p+=1

# %%
if cust_dfs_new:
    for key,val in custField.items():

        if categories and val[0]:
            clientDic = {key : val[1][key] for key in val[1] if key in custCatDic}
            totalDic = {key : val[0][key] for key in val[0] if key in categories}

            shareGrowth(prs,clientDic,totalDic,catSecSeg,col=key,position = calculate_position(p)) 
            p+=1
    for key,val in custField.items():

        if sectors and val[0]:   
            clientDic = {key : val[1][key] for key in val[1] if key in custSecDic}
            totalDic = {key : val[0][key] for key in val[0] if key in sectors}

            shareGrowth(prs,clientDic,totalDic,catSecSeg,col=key,position = calculate_position(p)) 
            p+=1

    for key,val in custField.items():

        if segments and val[0]: 
            clientDic = {key : val[1][key] for key in val[1] if key in custSegDic}
            totalDic = {key : val[0][key] for key in val[0] if key in segments}

            shareGrowth(prs,clientDic,totalDic,catSecSeg,col='Channel',position = calculate_position(p)) 
            p+=1
    for key,val in custField.items():

        if subsegments and val[0]:
            clientDic = {key : val[1][key] for key in val[1] if key in custSubSegDic}
            totalDic = {key : val[0][key] for key in val[0] if key in subsegments}

            shareGrowth(prs,clientDic,totalDic,catSecSeg,col=key,position = calculate_position(p)) 
            p+=1

            
    for key,val in custField.items():

        if subcategories and val[0]:
            clientDic = {key : val[1][key] for key in val[1] if key in custSubCatDic}
            totalDic = {key : val[0][key] for key in val[0] if key in subcategories}

            shareGrowth(prs,clientDic,totalDic,catSecSeg,col=key,position = calculate_position(p)) 
            p+=1

# %%
custField['Channel'][1]['Duplo | 2 Blades']
# Out:
# 12       Region            Channel Market     WoB % WoB % DYA  \
# 22  Grand Total                NaN    NaN         1         0
# 19          NaN  Drugstores Area 4    NaN  0.527024  0.103887
# 17          NaN  Drugstores Area 3    NaN  0.320993 -0.106786
# 13          NaN  Drugstores Area 1    NaN  0.083341  0.002677
# 15          NaN  Drugstores Area 2    NaN  0.068642  0.000221
#
# 12 Growth Contribution Value Sales Value Sales IYA Av Price/KG Relative Price  \
# 22                   1      384912        1.050994     0.23296       0.980833
# 19            2.564254      202858        1.309032    0.222691       0.937596
# 17           -1.773078      123554        0.788636    0.244664       1.030112
# 13            0.135843       32079        1.085878    0.239856       1.009865
# 15            0.072981       26421        1.054394    0.257542       1.084332
#
# 12  Value Share IYA Price/KG Value Share DYA
# 22     0.002986     1.092639        0.000015
# ...

# %%
len(custField['Channel'][1].keys())
for key,val in clientDic.items():
    print(key,val.shape)
# Out:
# Edgewell | 1 Blades (5, 13)
# Edgewell | 2 Blades (5, 13)
# Edgewell | 3 Blades (5, 13)
# Edgewell | 4 Blades (5, 13)
# Edgewell | 5 Blades (5, 13)
# Xtreme 3 | 3 Blades (5, 13)
# Extra 3 | 3 Blades (5, 13)
# Hydro | 3 Blades (5, 13)
# Hydro | 5 Blades (5, 13)
# Quattro Titanium | 4 Blades (5, 13)
# Classic | 2 Blades (5, 13)
# Quattro | 4 Blades (5, 13)
# Extra 2 | 2 Blades (5, 13)
# Duplo | 2 Blades (5, 13)

# %%
subcategories
# Out:
# ['1 Blades', '2 Blades', '3 Blades', '4 Blades', '5 Blades']

# %%
outputPath = os.getcwd()+"\\Landscape new slides output.pptx"

prs.save(outputPath)
app = win32.Dispatch("PowerPoint.Application")
presentation = app.Presentations.Open(outputPath)

# %%
end_time = time.time()

elapsed_time = end_time - start_time
print(f"Script started at: {time.ctime(start_time)}")
print(f"Script ended at: {time.ctime(end_time)}")
print(f"Elapsed time: {elapsed_time:.2f} seconds")
# Out:
# Script started at: Wed Jul 31 14:56:37 2024
# Script ended at: Wed Jul 31 14:58:50 2024
# Elapsed time: 132.83 seconds

# %%
# 326.26

# %%
# modified_retailer_regions = {}
# modified_retailer_channels = {}
# modified_retailer_markets = {}

# modified_channels_regions = {}
# modified_channels_channels = {}
# modified_channels_markets = {}

# modified_cust_regions = {}
# modified_cust_channels = {}
# modified_cust_markets = {}

# dya_retailer={}
# dya_channel={}
# dya_cust = {}

# for table in retailers_dfs_new.keys():
#     t = retailers_dfs_new[table].copy()
#     t.columns = t.iloc[12]
#     t = t.iloc[t[t[t.columns[0]]==t.columns[0]].index[0]+1:]
#     t = t.applymap(lambda x: float(x) if pd.to_numeric(x, errors='coerce') == x else x)
#     gran_tot = t[t['Region'] == "Grand Total"]
#     t['Channel'] = np.where(t['Channel'].isna(), t['Region'], t['Channel'])
#     t['Market'] = np.where(t['Market'].isna(), t['Channel'], t['Market'])
#     t['Region'] = t['Region'].ffill()
    
#     r = t[(t['Region'].str.contains('Total'))]
#     r = r[r.Region.str.replace('Total','').str.strip().isin(regions_RET)].drop(columns = ['Channel','Market'])
#     r['Region'] = r['Region'].str.replace('Total', '').str.strip()
#     r['Value Share'] = r['Value Share'].astype(float)
#     r = r.sort_values('Value Share', ascending=False)
#     r=r.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     r.columns = r.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     r = r.sort_values('WoB %', ascending=False)  
#     r = r.drop_duplicates()
    
#     c = t[t['Channel'].isin(c +' Total' for c in channels_RET)].drop(columns = ['Region','Market'])
#     c['Channel'] = c['Channel'].str.replace(' Total','')
#     c['Value Share'] = c['Value Share'].astype(float) 
#     c = c.sort_values('Value Share', ascending=False)
#     c=c.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     c.columns = c.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     c = c.sort_values('WoB %', ascending=False)
#     c = c.drop_duplicates()
    
#     m = t[t['Market'].isin(market_RET)].drop(columns = ['Region','Channel'])
#     m['Value Share'] = m['Value Share'].astype(float) 
#     m = m.sort_values('Value Share', ascending=False)
#     m=m.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     m.columns = m.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     m = m.sort_values('WoB %', ascending=False)
#     m = m.drop_duplicates()
    
#     if not r.empty:
#         modified_retailer_regions[table] = r 
#     if not c.empty:
#         modified_retailer_channels[table] = c
#     if not m.empty:
#         modified_retailer_markets[table] = m
#     if not gran_tot.empty:
#         dya_retailer[table] = gran_tot



# for table in channel_dfs_new.keys():
#     t = channel_dfs_new[table].copy()
#     t.columns = t.iloc[12]
#     t = t.iloc[t[t[t.columns[0]]==t.columns[0]].index[0]+1:]
#     gran_tot = t[t['Region'] == "Grand Total"]
#     t['Channel'] = np.where(t['Channel'].isna(), t['Region'], t['Channel'])
#     t['Market'] = np.where(t['Market'].isna(), t['Channel'], t['Market'])
#     t['Region'] = t['Region'].ffill()

#     r = t[(t['Region'].str.contains('Total'))]
#     r = r[r.Region.str.replace('Total','').str.strip().isin(regions_CHAN)].drop(columns = ['Channel','Market'])
#     r['Region'] = r['Region'].str.replace('Total', '').str.strip()
#     r['Value Share'] = r['Value Share'].astype(float)
#     r = r.sort_values('Value Share', ascending=False)
#     r=r.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     r.columns = r.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     r = r.sort_values('WoB %', ascending=False)
#     r = r.drop_duplicates()
    
#     c = t[t['Channel'].isin(c +' Total' for c in channels_CHAN)].drop(columns = ['Region', 'Market'])
#     c['Channel'] = c['Channel'].str.replace(' Total','')
#     c['Value Share'] = c['Value Share'].astype(float) 
#     c = c.sort_values('Value Share', ascending=False)
#     c=c.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     c.columns = c.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     c = c.sort_values('WoB %', ascending=False)
#     c = c.drop_duplicates()
    
#     m = t[t['Market'].isin(market_CHAN)].drop(columns = ['Region','Channel'])
#     m['Value Share'] = m['Value Share'].astype(float) 
#     m = m.sort_values('Value Share', ascending=False)
#     m=m.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     m.columns = m.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     m = m.sort_values('WoB %', ascending=False)
#     m = m.drop_duplicates()
    
#     if not r.empty:
#         modified_channels_regions[table] = r
#     if not c.empty:
#         modified_channels_channels[table] = c
#     if not m.empty:
#         modified_channels_markets[table] = m
#     if not gran_tot.empty:
#         dya_channel[table] = gran_tot



# for table in cust_dfs_new.keys():
#     t = cust_dfs_new[table].copy()
#     t.columns = t.iloc[12]
#     t = t.iloc[t[t[t.columns[0]]==t.columns[0]].index[0]+1:]
#     gran_tot = t[t['Region'] == "Grand Total"]
#     t['Channel'] = np.where(t['Channel'].isna(), t['Region'], t['Channel'])
#     t['Market'] = np.where(t['Market'].isna(), t['Channel'], t['Market'])
#     t['Region'] = t['Region'].ffill()

#     r = t[(t['Region'].str.contains('Total'))]
#     r = r[r.Region.str.replace('Total','').str.strip().isin(regions_CUST)].drop(columns = ['Channel','Market'])
#     r['Region'] = r['Region'].str.replace('Total', '').str.strip()
#     r['Value Share'] = r['Value Share'].astype(float)
#     r = r.sort_values('Value Share', ascending=False)
#     r=r.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     r.columns = r.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     r = r.sort_values('WoB %', ascending=False)
#     r = r.drop_duplicates()
    
#     c = t[t['Channel'].isin(c +' Total' for c in channels_CUST)].drop(columns = ['Region', 'Market'])
#     c['Channel'] = c['Channel'].str.replace(' Total','')
#     c['Value Share'] = c['Value Share'].astype(float) 
#     c = c.sort_values('Value Share', ascending=False)
#     c=c.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     c.columns = c.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     c = c.sort_values('WoB %', ascending=False)
#     c = c.drop_duplicates()
    
#     m = t[t['Market'].isin(market_CUST)].drop(columns = ['Region','Channel'])
#     m['Value Share'] = m['Value Share'].astype(float) 
#     m = m.sort_values('Value Share', ascending=False)
#     m=m.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     m.columns = m.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     m = m.sort_values('WoB %', ascending=False)
#     m = m.drop_duplicates()
    
#     if not r.empty:
#         modified_cust_regions[table] = r
#     if not c.empty:
#         modified_cust_channels[table] = c
#     if not m.empty:
#         modified_cust_markets[table] = m
#     if not gran_tot.empty:
#         dya_cust[table] = gran_tot

# %%
# modified_retailer_regions_client = {}
# modified_retailer_channels_client = {}
# modified_retailer_markets_client = {}

# modified_channels_regions_client = {}
# modified_channels_channels_client = {}
# modified_channels_markets_client = {}

# modified_cust_regions_client = {}
# modified_cust_channels_client = {}
# modified_cust_markets_client = {}


# dya_retailer_client={}
# dya_channel_client={}
# dya_cust_client = {}

# for table in retailers_client_dfs_new.keys():
#     t = retailers_client_dfs_new[table].copy()
#     t.columns = t.iloc[12]
#     t = t.iloc[t[t[t.columns[0]]==t.columns[0]].index[0]+1:]
#     gran_tot = t[t['Region'] == "Grand Total"]
#     t['Channel'] = np.where(t['Channel'].isna(), t['Region'], t['Channel'])
#     t['Market'] = np.where(t['Market'].isna(), t['Channel'], t['Market'])
#     t['Region'] = t['Region'].ffill()
    
#     r = t[(t['Region'].str.contains('Total'))]
#     r = r[r.Region.str.replace('Total','').str.strip().isin(regions_RET)].drop(columns = ['Channel', 'Market'])
#     r['Region'] = r['Region'].str.replace('Total', '').str.strip()
#     r['Value Share'] = r['Value Share'].astype(float)
#     r = r.sort_values('Value Share', ascending=False)
#     r=r.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     r.columns = r.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     r = r.sort_values('WoB %', ascending=False)
#     r = r.drop_duplicates()
    
#     c = t[t['Channel'].isin(c+' Total' for c in channels_RET)].drop(columns = ['Region','Market'])
#     c['Channel'] = c['Channel'].str.replace(' Total', '')
#     c['Value Share'] = c['Value Share'].astype(float) 
#     c = c.sort_values('Value Share', ascending=False)
#     c=c.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     c.columns = c.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     c = c.sort_values('WoB %', ascending=False)
#     c = c.drop_duplicates()
    
#     m = t[t['Channel'].isin(market_RET)].drop(columns = ['Region','Channel'])
#     m['Value Share'] = m['Value Share'].astype(float) 
#     m = m.sort_values('Value Share', ascending=False)
#     m=m.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     m.columns = m.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     m = m.sort_values('WoB %', ascending=False)
#     m = m.drop_duplicates()
    
#     if not r.empty:
#         modified_retailer_regions_client[table] = r 
#     if not c.empty:   
#         modified_retailer_channels_client[table] = c
#     if not m.empty:
#         modified_retailer_markets_client[table] = m
#     if not gran_tot.empty:    
#         dya_retailer_client[table] = gran_tot


# for table in channel_client_dfs_new.keys():
#     t = channel_client_dfs_new[table].copy()
#     t.columns = t.iloc[12]
#     t = t.iloc[t[t[t.columns[0]]==t.columns[0]].index[0]+1:]
#     gran_tot = t[t['Region'] == "Grand Total"]
#     t['Channel'] = np.where(t['Channel'].isna(), t['Region'], t['Channel'])
#     t['Market'] = np.where(t['Market'].isna(), t['Channel'], t['Market'])
#     t['Region'] = t['Region'].ffill()
    
#     r = t[(t['Region'].str.contains('Total'))]
#     r = r[r.Region.str.replace('Total','').str.strip().isin(regions_CHAN)].drop(columns = ['Channel','Market'])
#     r['Region'] = r['Region'].str.replace('Total', '').str.strip()
#     r['Value Share'] = r['Value Share'].astype(float)
#     r = r.sort_values('Value Share', ascending=False)
#     r=r.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     r.columns = r.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     r = r.sort_values('WoB %', ascending=False)
#     r = r.drop_duplicates()
    
#     c = t[t['Channel'].isin(c+' Total' for c in channels_CHAN)].drop(columns = ['Region','Market'])
#     c['Channel'] = c['Channel'].str.replace(' Total', '')
#     c['Value Share'] = c['Value Share'].astype(float) 
#     c = c.sort_values('Value Share', ascending=False)
#     c=c.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     c.columns = c.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     c = c.sort_values('WoB %', ascending=False)
#     c = c.drop_duplicates()
    
#     m = t[t['Market'].isin(market_CHAN)].drop(columns = ['Region','Channel'])
#     m['Value Share'] = m['Value Share'].astype(float) 
#     m = m.sort_values('Value Share', ascending=False)
#     m=m.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     m.columns = m.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     m = m.sort_values('WoB %', ascending=False)
#     m = m.drop_duplicates()
    
#     if not r.empty:
#         modified_channels_regions_client[table] = r
#     if not c.empty:    
#         modified_channels_channels_client[table] = c
#     if not m.empty:    
#         modified_channels_markets_client[table] = m
#     if not gran_tot.empty:
#         dya_channel_client[table] = gran_tot

# for table in cust_client_dfs_new.keys():
#     t = cust_client_dfs_new[table].copy()
#     t.columns = t.iloc[12]
#     t = t.iloc[t[t[t.columns[0]]==t.columns[0]].index[0]+1:]
#     gran_tot = t[t['Region'] == "Grand Total"]
#     t['Channel'] = np.where(t['Channel'].isna(), t['Region'], t['Channel'])
#     t['Market'] = np.where(t['Market'].isna(), t['Channel'], t['Market'])
#     t['Region'] = t['Region'].ffill()
    
#     r = t[(t['Region'].str.contains('Total'))]
#     r = r[r.Region.str.replace('Total','').str.strip().isin(regions_CUST)].drop(columns = ['Channel','Market'])
#     r['Region'] = r['Region'].str.replace('Total', '').str.strip()
#     r['Value Share'] = r['Value Share'].astype(float)
#     r = r.sort_values('Value Share', ascending=False)
#     r=r.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     r.columns = r.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     r = r.sort_values('WoB %', ascending=False)
#     r = r.drop_duplicates()
    
#     c = t[t['Channel'].isin(c+' Total' for c in channels_CUST)].drop(columns = ['Region','Market'])
#     c['Channel'] = c['Channel'].str.replace(' Total', '')
#     c['Value Share'] = c['Value Share'].astype(float) 
#     c = c.sort_values('Value Share', ascending=False)
#     c=c.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     c.columns = c.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     c = c.sort_values('WoB %', ascending=False)
#     c=c.drop_duplicates()
    
#     m = t[t['Market'].isin(market_CUST)].drop(columns = ['Region','Channel'])
#     m['Value Share'] = m['Value Share'].astype(float) 
#     m = m.sort_values('Value Share', ascending=False)
#     m=m.drop(columns=['WoB %', "Relative Price", "Growth Contribution"])
#     m.columns = m.columns.str.replace('Trade ', '').str.replace('Channel ','').str.strip()
#     m = m.sort_values('WoB %', ascending=False)
#     m = m.drop_duplicates()
    
#     if not r.empty:
#         modified_cust_regions_client[table] = r
#     if not c.empty:    
#         modified_cust_channels_client[table] = c
#     if not m.empty:
#         modified_cust_markets_client[table] = m
#     if not gran_tot.empty:
#         dya_cust_client[table] = gran_tot
