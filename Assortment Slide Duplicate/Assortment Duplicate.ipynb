# %%
# %run "..\general_functions\generalFunctions.ipynb"
# %run "..\Assortment Slide Duplicate\Assortment Replacement Function.ipynb"

# %%
ManufOrTopC ="Top Companies" #Manufacturer or Top Companies
BrandOrTopB= "Top Brands" #Brand or Top Brands
prodORitem="Product"

client_manuf = ["Edgewell"]
client_brands = ["Billie","Hydro Silk","Intuition","Skintimate"]

decimals = 2
sign = "Before"
currency = '$'
currency = ' '+ currency if sign.lower() == 'after' else  currency + ' '

categories = ["Manual Shave Women"]
sectors = ["Disposable","System"]
segments = ["Disposable","Hybrid","Razors","Refills"]
subsegments= ["1 Blade", "2 Blade", "3 Blade", "4 Blade", "5 Blade", "6 Blade","Rem Blades"]
subcategories= ["Dry Skin","Normal Skin","Rem Types","Sensitive Skin"]

national = False
customareas= ""
areas = ["RETAILER"]#'NATIONAL',"CHANNEL",customareas]
 
regions_RET  = ["Amazon", "CVS Corp", "Walmart"]
channels_RET = ["Amazon 1P", "CVS", "Walmart Div1 Corp", "Walmart Nm Corp", "Walmart Sc Corp"]
market_RET = []
 
regions_CHAN = []
channels_CHAN = []
market_CHAN = []
 
regions_CUST = []
channels_CUST = []
market_CUST = []

data_source = "DATA SOURCE: Trade Panel/Retailer Data | Ending August 2024"
years = ['2021', '2022','2023']
end_date = "2024-09-01"


OpenEditData=True
unit = "‘00000s"
unitDeviation = 100000
client_brands_competitor = client_brands + ["Gillette Venus"]
valueToReplace = {}

# %%
loaded_data = {}
datasets_path = os.getcwd()+"/Assortment Datasets/"
datasets = os.listdir(datasets_path)
for d in datasets:
    with open(datasets_path+d, 'rb') as handle:
        globals()[d.split('.')[0]] = pd.read_pickle(handle)

# %%
def mixAssortmentCleaning(assortment, cumulativeShare):
    """
    Cleans and processes assortment and cumulative share data to provide modified data for brand-specific analysis.
    
    Args:
    assortment (dict): Dictionary containing assortment data.
    cumulativeShare (dict): Dictionary containing cumulative share data.
    
    Returns:
    tuple: 
        - assortmentModifiedBrand (dict): Dictionary containing cleaned and modified assortment data for brands.
        - assortmentModifiedTotal (dict): Dictionary containing cleaned and modified total assortment data.
        - assortmentClient (dict): Dictionary containing client-specific cleaned and modified assortment data.
    """
    
    # Initialize dictionaries to store modified data
    cumulativeShareModifiedBrand = {}
    assortmentModified = {}
    assortmentModifiedBrand = {}
    assortmentModifiedTotal = {}
    assortmentClient = {}

    # Process cumulative share data
    for key, value in cumulativeShare.items():
        dfcumulative=cumulativeShare[key].copy()
        dfcumulative=DetectHeader(dfcumulative)
        if dfcumulative.shape[0] != 0:  # If the dataframe is not empty
            newKey = key
            if key.split(' | ')[0] not in categories:  # Adjust key if it does not match category format
                newKey = key.split(' | ')[1] + ' | ' + key.split(' | ')[0]
            cumulativeShareModifiedBrand[newKey] = dfcumulative.replace(np.nan, 0)  # Replace NaNs with 0 and store

    # Process assortment data
    for key, value in assortment.items():
        df=assortment[key].copy()

        df=DetectHeader(df)
        df['Top Brands'] = df['Top Brands'].ffill()  # Forward fill 'Top Brands' column

        # Replace specific values in 'Top Brands' as per 'valueToReplace' dictionary
        for val, replacer in valueToReplace.items():
            df['Top Brands'] = df['Top Brands'].str.replace(val, replacer)
        
        dfBrand = df[~df['Top Brands'].str.contains('Total')]  # Filter out rows containing 'Total' in 'Top Brands'
        dfTotal = df[df['Top Brands'].str.contains('Total') & (df['Top Brands'] != 'Grand Total')].reset_index(drop=True)
        dfTotal['Top Brands'] = dfTotal['Top Brands'].str.replace(' Total', '')  # Adjust 'Top Brands' column for total rows

        if df.shape[0] != 0:  # If the dataframe is not empty
            newKey = key
            if key.split(' | ')[0] not in categories:  # Adjust key if it does not match category format
                newKey = key.split(' | ')[1] + ' | ' + key.split(' | ')[0]
            
            # Process client-specific data for each brand
            for brand in client_brands_competitor:

                if df[df['Top Brands'] == brand].shape[0] > 0:  # Check if brand data exists in dataframe

                    #assortmentClient[newKey + ' | ' + brand] = df[df['Top Brands'] == brand].replace(np.nan, 0)
                    brand_df = df[df['Top Brands'] == brand].replace(np.nan, 0) 
                    brand_df = brand_df.sort_values(by='Value Share', ascending = False)
                    brand_df['Value Share Rescale'] = brand_df['Value Share'] / sum(brand_df['Value Share'])
                    brand_df['Cumulative Share'] = brand_df['Value Share Rescale'].cumsum()
                    #brand_df['Final Cumlative Share'] = 100 - brand_df['Cumlative Share']*100
                    assortmentClient[newKey + ' | ' + brand] = brand_df.merge(
                        cumulativeShareModifiedBrand[newKey], how='left', on= prodORitem
                    )
                    #assortmentClient[newKey + ' | ' + brand] = assortmentClient[newKey + ' | ' + brand].merge(
                    #    cumulativeShareModifiedBrand[newKey], how='left', on= prodORitem
                    #)

            
            # Store modified data for total, brand, and overall assortment
            assortmentModified[newKey] = df.replace(np.nan, 0)
            assortmentModifiedBrand[newKey] = dfBrand.replace(np.nan, 0).drop(columns=['Cumulative '+prodORitem+' Share'])
            assortmentModifiedBrand[newKey] = assortmentModifiedBrand[newKey].merge(
                cumulativeShareModifiedBrand[newKey], how='left', on=prodORitem
            )
            assortmentModifiedTotal[newKey] = dfTotal.replace(np.nan, 0)
    
    return assortmentModifiedBrand, assortmentModifiedTotal, assortmentClient

# %%
"""
Cleans and processes assortment for brand-specific analysis.

Args:
assortmentbybrand (dict): Dictionary containing assortment data by brand.

Returns:
tuple: 
   - assortmentModifiedBrand (dict): Dictionary containing cleaned and modified assortment data by brand for slide 1
"""

# Initialize dictionaries to store modified data
assortmentbybrandfinal = {}
# Process assortment data
for key, value in assortmentbybrand.items():
   df=assortmentbybrand[key].copy()
   df=DetectHeader(df)
   if BrandOrTopB != "Top Brands":
      df= df.rename(columns={"Brand":"Top Brands"})
   # Replace specific values in 'Top Brands' as per 'valueToReplace' dictionary
   for val, replacer in valueToReplace.items():
      df['Top Brands'] = df['Top Brands'].str.replace(val, replacer)
   
   dfBrand = df[df['Top Brands'] != 'Grand Total'].reset_index(drop=True)
   if df.shape[0] != 0:  # If the dataframe is not empty
      newKey = key
      if key.split(' | ')[0] not in categories:  # Adjust key if it does not match category format
            newKey = key.split(' | ')[1] + ' | ' + key.split(' | ')[0]
   # Store modified data for total, brand, and overall assortment
      assortmentbybrandfinal[newKey] = dfBrand.replace(np.nan, 0)

# %%
"""
Cleans and processes assortment for brand-specific analysis.

Args:
assortmentbybrand (dict): Dictionary containing assortment data by brand.

Returns:
tuple: 
   - assortmentModifiedBrand (dict): Dictionary containing cleaned and modified assortment data by brand for slide 1
"""

# Initialize dictionaries to store modified data
assortmentbymanufFinal = {}
# Process assortment data
for key, value in assortmentbymanuf.items():
   df=assortmentbymanuf[key].copy()
   df=DetectHeader(df)
   dfManuf = df[df[ManufOrTopC] != 'Grand Total'].reset_index(drop=True)
   dfManuf = dfManuf[dfManuf[ManufOrTopC] != 'All Others'].reset_index(drop=True)
   if dfManuf.shape[0] != 0:  # If the dataframe is not empty
      newKey = key
      if df.shape[0] != 0:  # If the dataframe is not empty
         newKey = key
         if key.split(' | ')[0] not in categories:  # Adjust key if it does not match category format
            newKey = key.split(' | ')[1] + ' | ' + key.split(' | ')[0]
         assortmentbymanufFinal[newKey] = dfManuf.replace(np.nan, 0)

# %%
assortmentBrandSorted= dfSort(assortmentbybrandfinal, client_brands, 'Top Brands', num=10,salesCol='Value Share')

# %%
assortmentManufSorted= dfSort(assortmentbymanufFinal, [], ManufOrTopC, num=10,salesCol='Value Share')

# %%
assortmentBrandNOTSorted= dfSort(assortmentbybrandfinal, [], 'Top Brands', num=10,salesCol='Value Share')

# %%
assortmentBrand,assortmentTotal,assortmentClient=mixAssortmentCleaning(assortment,cumulative_share)

# %%
assortmentTotalSorted= dfSort(assortmentTotal, client_brands, 'Top Brands', num=10,salesCol='Value Share')

# %% [markdown]
# ### Slide 3,4 cumulative share Cleaning

# %%
def cumulativeShareCleaningTopPercent(assortment, cumulativeShare, percent=0.5):
    """
    Cleans and processes assortment and cumulative share data, filtering out the top percentage of products.
    
    Args:
    assortment (dict): Dictionary containing assortment data.
    cumulativeShare (dict): Dictionary containing cumulative share data.
    percent (float): The top cumulative product share percentage threshold to filter by (default is 0.5).
    
    Returns:
    dict: A dictionary containing the cleaned and processed data for the top percentage of products.
    """
    
    # Initialize dictionaries to store modified data
    assortmentModified = {}
    assortmentModifiedBrand = {}
    topPercent = {}
    cumulativeShareModifiedBrand = {}

    # Process cumulative share data
    for key, value in cumulativeShare.items():
        dfcumulative=cumulativeShare[key].copy()
        dfcumulative=DetectHeader(dfcumulative)
        if dfcumulative.shape[0] != 0:  # If the dataframe is not empty
            newKey = key
            if key.split(' | ')[0] not in categories:  # Adjust key if it does not match category format
                newKey = key.split(' | ')[1] + ' | ' + key.split(' | ')[0]
            cumulativeShareModifiedBrand[newKey] = dfcumulative.replace(np.nan, 0)  # Replace NaNs with 0 and store

    # Process assortment data
    for key, value in assortment.items():
        df=assortment[key].copy()
        df=DetectHeader(df)
        if BrandOrTopB != "Top Brands":
            df= df.rename(columns={"Brand":"Top Brands"})
        df['Top Brands'] = df['Top Brands'].ffill()  # Forward fill 'Top Brands' column
        
        # Replace specific values in 'Top Brands' as per 'valueToReplace' dictionary
        for val, replacer in valueToReplace.items():
            df['Top Brands'] = df['Top Brands'].str.replace(val, replacer)
        
        dfBrand = df[~df['Top Brands'].str.contains('Total')]  # Filter out rows containing 'Total' in 'Top Brands'
        
        if df.shape[0] != 0:  # If the dataframe is not empty
            newKey = key
            if key.split(' | ')[0] not in categories:  # Adjust key if it does not match category format
                newKey = key.split(' | ')[1] + ' | ' + key.split(' | ')[0]
            
            # Store modified data for overall and brand-specific assortment
            assortmentModified[newKey] = df.replace(np.nan, 0)
            assortmentModifiedBrand[newKey] = dfBrand.replace(np.nan, 0).drop(columns=['Cumulative '+prodORitem+' Share'])
            assortmentModifiedBrand[newKey] = assortmentModifiedBrand[newKey].merge(
                cumulativeShareModifiedBrand[newKey], how='left', on=prodORitem
            )
            
            # Filter and store data for products within the specified cumulative share percentage
            # if (assortmentModifiedBrand[newKey][assortmentModifiedBrand[newKey]['Cumulative '+prodORitem+' Share'] <= percent].shape[0] > 0):
            
            topPercent[newKey] = assortmentModifiedBrand[newKey]

    return topPercent

# %%
cumulativeShareTop50 = cumulativeShareCleaningTopPercent(assortment,cumulative_share, percent =0.5)

# %%
cumulativeShareAll = cumulativeShareCleaningTopPercent(assortment,cumulative_share, percent =100)

# %% [markdown]
# ### Slide 6,7 SKU Productivity Analysis Cleaning

# %%
def productivityAnalysisCleaning(assortmentModifiedBrand):
    """
    Cleans and filters the assortment data for client brands based on specific criteria.
    
    Args:
    assortmentModifiedBrand (dict): Dictionary containing modified assortment data by brand.
    
    Returns:
    dict: A dictionary containing the cleaned and filtered data for each client brand.
    """
    
    assortmentClientBrand = {}  # Initialize a dictionary to store the cleaned data for client brands
    
    # Iterate over the modified assortment data
    for key, value in assortmentModifiedBrand.items():
        # Filter the dataframe for client brands with Net Sales >= 1000 and WD not equal to 0
        df = value[(value['Top Brands'].isin(client_brands)) & (value['Net Sales'] >= 1000)]
        df = df[df['WD'] != 0]
        
        # If the filtered dataframe is not empty
        if df.shape[0] != 0:
            # Iterate over each client brand
            for brand in client_brands:
                # If the brand exists in the filtered dataframe
                if df[df['Top Brands'] == brand].shape[0] > 0:
                    # Store the filtered data in the dictionary with a combined key of original key and brand name
                    assortmentClientBrand[key + ' | ' + brand] = df[df['Top Brands'] == brand]
    
    return assortmentClientBrand

# %%
assortmentClientBrand=productivityAnalysisCleaning(assortmentBrand)

# %% [markdown]
# ## New Slide

# %%
def clean_brand(brands):
    new_brands ={}
    for key, df in brands.items():
        new_df = DetectHeader(df)
        if new_df.shape[0] != 0:  
            newKey = key
            if key.split(' | ')[0] not in categories:  
                newKey = key.split(' | ')[1] + ' | ' + key.split(' | ')[0]
            new_brands[newKey] = new_df.replace(np.nan, -1)  
    return new_brands

# %%
def clean_manuf(manuf):
    new_manuf ={}
    for key, df in manuf.items():
        new_df = DetectHeader(df)
        if new_df.shape[0] != 0:  
            newKey = key
            if key.split(' | ')[0] not in categories:  
                newKey = key.split(' | ')[1] + ' | ' + key.split(' | ')[0]
            new_manuf[newKey] = new_df.replace(np.nan, -1)  
    return new_manuf

# %%
def clean_total(total):
    new_total ={}
    for key, df in total.items():
        new_df = DetectHeader(df)
        if new_df.shape[0] != 0:
            new_df = new_df.drop(['SKU Share', 'Value Share'], axis=1)
            new_total[key] = new_df.replace(np.nan, -1) 
    return new_total

# %%
def merge_total_brand(total, brand, column,scope):
    brand_total ={}
    for key in brand.keys():
        market = key.split(' | ')[0]
        for small_key in total.keys():
            if market == small_key:
                # print(market, small_key, key)
                df = pd.merge(total[small_key], brand[key], how = 'left',on=column,suffixes=('_total', '_brand')).replace(np.nan,0)
                df['Fair Share'] = df.apply(lambda x: ((x['Av No SKUs_brand'] / x['SKU Share']) * x['Value Share'] if x['SKU Share'] != 0 else 0), axis=1)
                df ['Listing Opportunity'] = df['Fair Share'].astype(float).round(0) - df['Av No SKUs_brand'].astype(float).round(0)
                grand_row = df[df[column] == 'Grand Total']
                other_rows = df[df[column].isin(scope)]
                df = pd.concat([grand_row, other_rows], ignore_index=True)
                if df.shape[0] > 0:
                    brand_total[key] = df

    return brand_total

# %%
if len(sectors) > 0:
    Sector_brands = clean_brand(Sector_dfs_brands)
    Sector_manuf = clean_manuf(Sector_dfs_manuf)
    Sector_total = clean_total(Sector_dfs_total)
    Sector_brand_total = merge_total_brand(Sector_total, Sector_brands, 'Sector',sectors)
    Sector_manuf_total = merge_total_brand(Sector_total, Sector_manuf, 'Sector',sectors)
    final_Sector = Sector_manuf_total | Sector_brand_total


if len(segments) > 0:
    Segment_brands = clean_brand(Segment_dfs_brands)
    Segment_manuf = clean_manuf(Segment_dfs_manuf)
    Segment_total = clean_total(Segment_dfs_total)
    Segment_brand_total = merge_total_brand(Segment_total, Segment_brands, 'Segment',segments)
    Segment_manuf_total = merge_total_brand(Segment_total, Segment_manuf, 'Segment',segments)
    final_Segment = Segment_manuf_total | Segment_brand_total


if len(subcategories) > 0:
    SubCategory_brands = clean_brand(SubCategory_dfs_brands)
    SubCategory_manuf = clean_manuf(SubCategory_dfs_manuf)
    SubCategory_total = clean_total(SubCategory_dfs_total)
    SubCategory_brand_total = merge_total_brand(SubCategory_total, SubCategory_brands, 'SubCategory',subcategories)
    SubCategory_manuf_total = merge_total_brand(SubCategory_total, SubCategory_manuf, 'SubCategory',subcategories)
    final_SubCategory = SubCategory_manuf_total | SubCategory_brand_total


if len(subsegments) > 0:
    Subsegment_brands = clean_brand(SubSegment_dfs_brands)
    Subsegment_manuf = clean_manuf(SubSegment_dfs_manuf)
    Subsegment_total = clean_total(SubSegment_dfs_total)
    Subsegment_brand_total = merge_total_brand(Subsegment_total, Subsegment_brands,'SubSegment',subsegments)
    Subsegment_manuf_total = merge_total_brand(Subsegment_total, Subsegment_manuf,'SubSegment',subsegments)
    final_Subsegment = Subsegment_manuf_total | Subsegment_brand_total

# %% [markdown]
# ## Duplication Stage

# %%
index = [0,0,1,2,3 if len(client_brands)>0 else None ,4,5 if len(client_brands)>0 else None,6 if len(client_brands)>0 else None, *[7]*((1 if sectors else 0) + (1 if segments else 0) + (1 if subsegments else 0) + (1 if subcategories else 0)),0]
index = [x for x in index if x is not None]

duplication = [len(assortmentBrandSorted.keys()),len(assortmentManufSorted.keys()),len(assortmentBrand.keys()),len(cumulativeShareTop50.keys()), len(assortmentClient.keys()) if len(client_brands) >0 else None,len(assortmentBrand.keys()) , len(assortmentClientBrand.keys()) if len(client_brands)>0 else None , len(assortmentClientBrand.keys()) if len(client_brands)>0 else None,
               len(final_Sector.keys()) if len(sectors) >0 else None, len(final_Segment.keys()) if len(segments) > 0 else None, len(final_SubCategory.keys()) if len(subcategories) >0 else None, len(final_Subsegment.keys()) if len(subsegments) > 0 else None ,len(assortmentBrandNOTSorted.keys())]
duplication = [x for x in duplication if x is not None]

section_names = ["SKU Share By Brand","SKU Share by Manuf","Cumulative Product Shares","Top 50% cumulative share","Brand Cumulative Product Share" if len(client_brands) >0 else None,"Top 20 cumulative share","SKU Productivity Analysis with TM%" if len(client_brands)>0 else None, "SKU Productivity Analysis with WD" if len(client_brands)>0  else None,
                 "Sectors Fair Share" if len(sectors) > 0 else None, "Segments Fair Share" if len(segments) > 0 else None, "SubCategory Fair Share" if len(subcategories) > 0 else None, "SubSegment Fair Share" if len(subsegments) > 0 else None,"SKU Share By Brand no client prio" ]
section_names = [x for x in section_names if x is not None]

path = os.getcwd() + '//Assortment base Oct 2024.pptx'
new_pre = os.getcwd() + '//slide duplicated1.pptx'


length = len(duplication)
for i in reversed(range(length)):
    if duplication[i]==0:
        del duplication[i]
        del index[i]
        del section_names[i]

# %%
print(len(index))
print(index)
print(len(duplication))
print(duplication)
print(len(section_names))
print(section_names)
# Out:
# 13
# [0, 0, 1, 2, 3, 4, 5, 6, 7, 7, 7, 7, 0]
# 13
# [132, 129, 132, 132, 440, 132, 285, 285, 40, 40, 40, 40, 132]
# 13
# ['SKU Share By Brand', 'SKU Share by Manuf', 'Cumulative Product Shares', 'Top 50% cumulative share', 'Brand Cumulative Product Share', 'Top 20 cumulative share', 'SKU Productivity Analysis with TM%', 'SKU Productivity Analysis with WD', 'Sectors Fair Share', 'Segments Fair Share', 'SubCategory Fair Share', 'SubSegment Fair Share', 'SKU Share By Brand no client prio']

# %%
sum(duplication)
# Out:
# 1959

# %%
slideDuplication(index,duplication,section_names,path,new_pre)

# %%
prs = Presentation(new_pre)

# %% [markdown]
# ### Slide 1

# %%
posItr = 0
ind=0
SkuShareByBrand(prs,assortmentBrandSorted,duplication[ind],BrandOrTopB,position=posItr)
posItr +=len(assortmentBrandSorted)
ind+=1

# %%
SkuShareByBrand(prs,assortmentManufSorted,duplication[ind],ManufOrTopC,position=posItr)
posItr += len(assortmentManufSorted)
ind+=1

# %% [markdown]
# ### Slide 2

# %%
CumulativeProductShare(prodORitem,prs,assortmentBrand,duplication[ind],position=posItr)
posItr+= len(assortmentBrand)
ind+=1

# %% [markdown]
# ### Slide 3

# %%
cumulativeTop50(prodORitem,prs, cumulativeShareTop50,duplication[ind],position=posItr)
posItr +=len(cumulativeShareTop50)
ind+=1

# %% [markdown]
# ### Slide 4

# %%
if len(client_brands)>0:
    brandCumulativeProductShare(prodORitem,prs,assortmentClient,duplication[ind],position=posItr)
    posItr +=len(assortmentClient)
    ind+=1

# %% [markdown]
# ### Slide 5

# %%
top20CumulativeShare(prodORitem,prs,assortmentBrand,duplication[ind],position=posItr)
posItr+= len(assortmentBrand)
ind+=1

# %% [markdown]
# ### Slide 6

# %%
if len(client_brands)>0:
    SKUProductivityAnalysis(prodORitem,prs,assortmentClientBrand,duplication[ind],position=posItr)
    posItr += len(assortmentClientBrand)
    ind+=1

# %% [markdown]
# ### Slide 7

# %%
if len(client_brands)>0:
    SKUWithWD(prodORitem,prs,assortmentClientBrand,duplication[ind],position=posItr)
    posItr += len(assortmentClientBrand)
    ind+=1

# %% [markdown]
# ### Slide 8

# %%
if len(sectors)>0:
    fair_share(final_Sector,prs ,scope ='Sector', position=posItr,category = categories[0])
    posItr += len(final_Sector)
    ind+=1

# %%
if len(segments)>0:
    fair_share(final_Segment,prs ,scope='Segment', position=posItr,category =categories[0])
    posItr += len(final_Segment)
    ind+=1

# %%
if len(subcategories)>0:
    fair_share(final_SubCategory,prs ,scope='SubCategory', position=posItr,category =categories[0])
    posItr += len(final_SubCategory)
    ind+=1

# %%
if len(subsegments)>0:
    fair_share(final_Subsegment,prs ,scope='SubSegment', position=posItr,category =categories[0])
    posItr += len(final_Subsegment)
    ind+=1

# %% [markdown]
# ### Slide 1 without forcing client brand

# %%
SkuShareByBrand(prs,assortmentBrandNOTSorted,duplication[ind],BrandOrTopB,position=posItr)

# %%
outputPath=os.getcwd() + "\\Mix and assortment preoutput.pptx"
prs.save(outputPath)
app = win32.Dispatch("PowerPoint.Application")
#presentation = app.Presentations.Open(outputPath)

# %%
final=os.getcwd() + "\Mix and assortment output.pptx"

# %%
# Example usage
pptx_path = outputPath  # Replace with the actual path to your PPTX file
output_pptx_path=final
open_chart_data_in_excel(pptx_path,output_pptx_path)
# Out:
# Slide 1098: Opened Excel workbook: Book1
# Slide 1099: Opened Excel workbook: Book1
# Slide 1100: Opened Excel workbook: Book1
# Slide 1101: Opened Excel workbook: Book1
# Slide 1102: Opened Excel workbook: Book1
# Slide 1103: Opened Excel workbook: Book1
# Slide 1104: Opened Excel workbook: Book1
# Slide 1105: Opened Excel workbook: Book1
# Slide 1106: Opened Excel workbook: Book1
# Slide 1107: Opened Excel workbook: Book1
# Slide 1108: Opened Excel workbook: Book1
# Slide 1109: Opened Excel workbook: Book1
# Slide 1110: Opened Excel workbook: Book1
# Slide 1111: Opened Excel workbook: Book1
# Slide 1112: Opened Excel workbook: Book1
# Slide 1113: Opened Excel workbook: Book1
# Slide 1114: Opened Excel workbook: Book1
# Slide 1115: Opened Excel workbook: Book1
# Slide 1116: Opened Excel workbook: Book1
# Slide 1117: Opened Excel workbook: Book1
# Slide 1118: Opened Excel workbook: Book1
# Slide 1119: Opened Excel workbook: Book1
# Slide 1120: Opened Excel workbook: Book1
# Slide 1121: Opened Excel workbook: Book1
# Slide 1122: Opened Excel workbook: Book1
# Slide 1123: Opened Excel workbook: Book1
# Slide 1124: Opened Excel workbook: Book1
# Slide 1125: Opened Excel workbook: Book1
# Slide 1126: Opened Excel workbook: Book1
# Slide 1127: Opened Excel workbook: Book1
# Slide 1128: Opened Excel workbook: Book1
# Slide 1129: Opened Excel workbook: Book1
# Slide 1130: Opened Excel workbook: Book1
# Slide 1131: Opened Excel workbook: Book1
# Slide 1132: Opened Excel workbook: Book1
# Slide 1133: Opened Excel workbook: Book1
# Slide 1134: Opened Excel workbook: Book1
# Slide 1135: Opened Excel workbook: Book1
# Slide 1136: Opened Excel workbook: Book1
# Slide 1137: Opened Excel workbook: Book1
# Slide 1138: Opened Excel workbook: Book1
# Slide 1139: Opened Excel workbook: Book1
# Slide 1140: Opened Excel workbook: Book1
# Slide 1141: Opened Excel workbook: Book1
# Slide 1142: Opened Excel workbook: Book1
# Slide 1143: Opened Excel workbook: Book1
# Slide 1144: Opened Excel workbook: Book1
# Slide 1145: Opened Excel workbook: Book1
# Slide 1146: Opened Excel workbook: Book1
# Slide 1147: Opened Excel workbook: Book1
# Slide 1148: Opened Excel workbook: Book1
# Slide 1149: Opened Excel workbook: Book1
# Slide 1150: Opened Excel workbook: Book1
# Slide 1151: Opened Excel workbook: Book1
# Slide 1152: Opened Excel workbook: Book1
# Slide 1153: Opened Excel workbook: Book1
# Slide 1154: Opened Excel workbook: Book1
# Slide 1155: Opened Excel workbook: Book1
# Slide 1156: Opened Excel workbook: Book1
# Slide 1157: Opened Excel workbook: Book1
# Slide 1158: Opened Excel workbook: Book1
# Slide 1159: Opened Excel workbook: Book1
# Slide 1160: Opened Excel workbook: Book1
# Slide 1161: Opened Excel workbook: Book1
# Slide 1162: Opened Excel workbook: Book1
# Slide 1163: Opened Excel workbook: Book1
# Slide 1164: Opened Excel workbook: Book1
# Slide 1165: Opened Excel workbook: Book1
# Slide 1166: Opened Excel workbook: Book1
# Slide 1167: Opened Excel workbook: Book1
# Slide 1168: Opened Excel workbook: Book1
# Slide 1169: Opened Excel workbook: Book1
# Slide 1170: Opened Excel workbook: Book1
# Slide 1171: Opened Excel workbook: Book1
# Slide 1172: Opened Excel workbook: Book1
# Slide 1173: Opened Excel workbook: Book1
# Slide 1174: Opened Excel workbook: Book1
# Slide 1175: Opened Excel workbook: Book1
# Slide 1176: Opened Excel workbook: Book1
# Slide 1177: Opened Excel workbook: Book1
# Slide 1178: Opened Excel workbook: Book1
# Slide 1179: Opened Excel workbook: Book1
# Slide 1180: Opened Excel workbook: Book1
# Slide 1181: Opened Excel workbook: Book1
# Slide 1182: Opened Excel workbook: Book1
# Slide 1183: Opened Excel workbook: Book1
# Slide 1184: Opened Excel workbook: Book1
# Slide 1185: Opened Excel workbook: Book1
# Slide 1186: Opened Excel workbook: Book1
# Slide 1187: Opened Excel workbook: Book1
# Slide 1188: Opened Excel workbook: Book1
# Slide 1189: Opened Excel workbook: Book1
# Slide 1190: Opened Excel workbook: Book1
# Slide 1191: Opened Excel workbook: Book1
# Slide 1192: Opened Excel workbook: Book1
# Slide 1193: Opened Excel workbook: Book1
# Slide 1194: Opened Excel workbook: Book1
# Slide 1195: Opened Excel workbook: Book1
# Slide 1196: Opened Excel workbook: Book1
# Slide 1197: Opened Excel workbook: Book1
# Slide 1198: Opened Excel workbook: Book1
# Slide 1199: Opened Excel workbook: Book1
# Slide 1200: Opened Excel workbook: Book1
# Slide 1201: Opened Excel workbook: Book1
# Slide 1202: Opened Excel workbook: Book1
# Slide 1203: Opened Excel workbook: Book1
# Slide 1204: Opened Excel workbook: Book1
# Slide 1205: Opened Excel workbook: Book1
# Slide 1206: Opened Excel workbook: Book1
# Slide 1207: Opened Excel workbook: Book1
# Slide 1208: Opened Excel workbook: Book1
# Slide 1209: Opened Excel workbook: Book1
# Slide 1210: Opened Excel workbook: Book1
# Slide 1211: Opened Excel workbook: Book1
# Slide 1212: Opened Excel workbook: Book1
# Slide 1213: Opened Excel workbook: Book1
# Slide 1214: Opened Excel workbook: Book1
# Slide 1215: Opened Excel workbook: Book1
# Slide 1216: Opened Excel workbook: Book1
# Slide 1217: Opened Excel workbook: Book1
# Slide 1218: Opened Excel workbook: Book1
# Slide 1219: Opened Excel workbook: Book1
# Slide 1220: Opened Excel workbook: Book1
# Slide 1221: Opened Excel workbook: Book1
# Slide 1222: Opened Excel workbook: Book1
# Slide 1223: Opened Excel workbook: Book1
# Slide 1224: Opened Excel workbook: Book1
# Slide 1225: Opened Excel workbook: Book1
# Slide 1226: Opened Excel workbook: Book1
# Slide 1227: Opened Excel workbook: Book1
# Slide 1228: Opened Excel workbook: Book1
# Slide 1229: Opened Excel workbook: Book1
# Slide 1230: Opened Excel workbook: Book1
# Slide 1231: Opened Excel workbook: Book1
# Slide 1232: Opened Excel workbook: Book1
# Slide 1233: Opened Excel workbook: Book1
# Slide 1234: Opened Excel workbook: Book1
# Slide 1235: Opened Excel workbook: Book1
# Slide 1236: Opened Excel workbook: Book1
# Slide 1237: Opened Excel workbook: Book1
# Slide 1238: Opened Excel workbook: Book1
# Slide 1239: Opened Excel workbook: Book1
# Slide 1240: Opened Excel workbook: Book1
# Slide 1241: Opened Excel workbook: Book1
# Slide 1242: Opened Excel workbook: Book1
# Slide 1243: Opened Excel workbook: Book1
# Slide 1244: Opened Excel workbook: Book1
# Slide 1245: Opened Excel workbook: Book1
# Slide 1246: Opened Excel workbook: Book1
# Slide 1247: Opened Excel workbook: Book1
# Slide 1248: Opened Excel workbook: Book1
# Slide 1249: Opened Excel workbook: Book1
# Slide 1250: Opened Excel workbook: Book1
# Slide 1251: Opened Excel workbook: Book1
# Slide 1252: Opened Excel workbook: Book1
# Slide 1253: Opened Excel workbook: Book1
# Slide 1254: Opened Excel workbook: Book1
# Slide 1255: Opened Excel workbook: Book1
# Slide 1256: Opened Excel workbook: Book1
# Slide 1257: Opened Excel workbook: Book1
# Slide 1258: Opened Excel workbook: Book1
# Slide 1259: Opened Excel workbook: Book1
# Slide 1260: Opened Excel workbook: Book1
# Slide 1261: Opened Excel workbook: Book1
# Slide 1262: Opened Excel workbook: Book1
# Slide 1263: Opened Excel workbook: Book1
# Slide 1264: Opened Excel workbook: Book1
# Slide 1265: Opened Excel workbook: Book1
# Slide 1266: Opened Excel workbook: Book1
# Slide 1267: Opened Excel workbook: Book1
# Slide 1268: Opened Excel workbook: Book1
# Slide 1269: Opened Excel workbook: Book1
# Slide 1270: Opened Excel workbook: Book1
# Slide 1271: Opened Excel workbook: Book1
# Slide 1272: Opened Excel workbook: Book1
# Slide 1273: Opened Excel workbook: Book1
# Slide 1274: Opened Excel workbook: Book1
# Slide 1275: Opened Excel workbook: Book1
# Slide 1276: Opened Excel workbook: Book1
# Slide 1277: Opened Excel workbook: Book1
# Slide 1278: Opened Excel workbook: Book1
# Slide 1279: Opened Excel workbook: Book1
# Slide 1280: Opened Excel workbook: Book1
# Slide 1281: Opened Excel workbook: Book1
# Slide 1282: Opened Excel workbook: Book1
# Slide 1283: Opened Excel workbook: Book1
# Slide 1284: Opened Excel workbook: Book1
# Slide 1285: Opened Excel workbook: Book1
# Slide 1286: Opened Excel workbook: Book1
# Slide 1287: Opened Excel workbook: Book1
# Slide 1288: Opened Excel workbook: Book1
# Slide 1289: Opened Excel workbook: Book1
# Slide 1290: Opened Excel workbook: Book1
# Slide 1291: Opened Excel workbook: Book1
# Slide 1292: Opened Excel workbook: Book1
# Slide 1293: Opened Excel workbook: Book1
# Slide 1294: Opened Excel workbook: Book1
# Slide 1295: Opened Excel workbook: Book1
# Slide 1296: Opened Excel workbook: Book1
# Slide 1297: Opened Excel workbook: Book1
# Slide 1298: Opened Excel workbook: Book1
# Slide 1299: Opened Excel workbook: Book1
# Slide 1300: Opened Excel workbook: Book1
# Slide 1301: Opened Excel workbook: Book1
# Slide 1302: Opened Excel workbook: Book1
# Slide 1303: Opened Excel workbook: Book1
# Slide 1304: Opened Excel workbook: Book1
# Slide 1305: Opened Excel workbook: Book1
# Slide 1306: Opened Excel workbook: Book1
# Slide 1307: Opened Excel workbook: Book1
# Slide 1308: Opened Excel workbook: Book1
# Slide 1309: Opened Excel workbook: Book1
# Slide 1310: Opened Excel workbook: Book1
# Slide 1311: Opened Excel workbook: Book1
# Slide 1312: Opened Excel workbook: Book1
# Slide 1313: Opened Excel workbook: Book1
# Slide 1314: Opened Excel workbook: Book1
# Slide 1315: Opened Excel workbook: Book1
# Slide 1316: Opened Excel workbook: Book1
# Slide 1317: Opened Excel workbook: Book1
# Slide 1318: Opened Excel workbook: Book1
# Slide 1319: Opened Excel workbook: Book1
# Slide 1320: Opened Excel workbook: Book1
# Slide 1321: Opened Excel workbook: Book1
# Slide 1322: Opened Excel workbook: Book1
# Slide 1323: Opened Excel workbook: Book1
# Slide 1324: Opened Excel workbook: Book1
# Slide 1325: Opened Excel workbook: Book1
# Slide 1326: Opened Excel workbook: Book1
# Slide 1327: Opened Excel workbook: Book1
# Slide 1328: Opened Excel workbook: Book1
# Slide 1329: Opened Excel workbook: Book1
# Slide 1330: Opened Excel workbook: Book1
# Slide 1331: Opened Excel workbook: Book1
# Slide 1332: Opened Excel workbook: Book1
# Slide 1333: Opened Excel workbook: Book1
# Slide 1334: Opened Excel workbook: Book1
# Slide 1335: Opened Excel workbook: Book1
# Slide 1336: Opened Excel workbook: Book1
# Slide 1337: Opened Excel workbook: Book1
# Slide 1338: Opened Excel workbook: Book1
# Slide 1339: Opened Excel workbook: Book1
# Slide 1340: Opened Excel workbook: Book1
# Slide 1341: Opened Excel workbook: Book1
# Slide 1342: Opened Excel workbook: Book1
# Slide 1343: Opened Excel workbook: Book1
# Slide 1344: Opened Excel workbook: Book1
# Slide 1345: Opened Excel workbook: Book1
# Slide 1346: Opened Excel workbook: Book1
# Slide 1347: Opened Excel workbook: Book1
# Slide 1348: Opened Excel workbook: Book1
# Slide 1349: Opened Excel workbook: Book1
# Slide 1350: Opened Excel workbook: Book1
# Slide 1351: Opened Excel workbook: Book1
# Slide 1352: Opened Excel workbook: Book1
# Slide 1353: Opened Excel workbook: Book1
# Slide 1354: Opened Excel workbook: Book1
# Slide 1355: Opened Excel workbook: Book1
# Slide 1356: Opened Excel workbook: Book1
# Slide 1357: Opened Excel workbook: Book1
# Slide 1358: Opened Excel workbook: Book1
# Slide 1359: Opened Excel workbook: Book1
# Slide 1360: Opened Excel workbook: Book1
# Slide 1361: Opened Excel workbook: Book1
# Slide 1362: Opened Excel workbook: Book1
# Slide 1363: Opened Excel workbook: Book1
# Slide 1364: Opened Excel workbook: Book1
# Slide 1365: Opened Excel workbook: Book1
# Slide 1366: Opened Excel workbook: Book1
# Slide 1367: Opened Excel workbook: Book1
# Slide 1368: Opened Excel workbook: Book1
# Slide 1369: Opened Excel workbook: Book1
# Slide 1370: Opened Excel workbook: Book1
# Slide 1371: Opened Excel workbook: Book1
# Slide 1372: Opened Excel workbook: Book1
# Slide 1373: Opened Excel workbook: Book1
# Slide 1374: Opened Excel workbook: Book1
# Slide 1375: Opened Excel workbook: Book1
# Slide 1376: Opened Excel workbook: Book1
# Slide 1377: Opened Excel workbook: Book1
# Slide 1378: Opened Excel workbook: Book1
# Slide 1379: Opened Excel workbook: Book1
# Slide 1380: Opened Excel workbook: Book1
# Slide 1381: Opened Excel workbook: Book1
# Slide 1382: Opened Excel workbook: Book1
# Slide 1383: Opened Excel workbook: Book1
# Slide 1384: Opened Excel workbook: Book1
# Slide 1385: Opened Excel workbook: Book1
# Slide 1386: Opened Excel workbook: Book1
# Slide 1387: Opened Excel workbook: Book1
# Slide 1388: Opened Excel workbook: Book1
# Slide 1389: Opened Excel workbook: Book1
# Slide 1390: Opened Excel workbook: Book1
# Slide 1391: Opened Excel workbook: Book1
# Slide 1392: Opened Excel workbook: Book1
# Slide 1393: Opened Excel workbook: Book1
# Slide 1394: Opened Excel workbook: Book1
# Slide 1395: Opened Excel workbook: Book1
# Slide 1396: Opened Excel workbook: Book1
# Slide 1397: Opened Excel workbook: Book1
# Slide 1398: Opened Excel workbook: Book1
# Slide 1399: Opened Excel workbook: Book1
# Slide 1400: Opened Excel workbook: Book1
# Slide 1401: Opened Excel workbook: Book1
# Slide 1402: Opened Excel workbook: Book1
# Slide 1403: Opened Excel workbook: Book1
# Slide 1404: Opened Excel workbook: Book1
# Slide 1405: Opened Excel workbook: Book1
# Slide 1406: Opened Excel workbook: Book1
# Slide 1407: Opened Excel workbook: Book1
# Slide 1408: Opened Excel workbook: Book1
# Slide 1409: Opened Excel workbook: Book1
# Slide 1410: Opened Excel workbook: Book1
# Slide 1411: Opened Excel workbook: Book1
# Slide 1412: Opened Excel workbook: Book1
# Slide 1413: Opened Excel workbook: Book1
# Slide 1414: Opened Excel workbook: Book1
# Slide 1415: Opened Excel workbook: Book1
# Slide 1416: Opened Excel workbook: Book1
# Slide 1417: Opened Excel workbook: Book1
# Slide 1418: Opened Excel workbook: Book1
# Slide 1419: Opened Excel workbook: Book1
# Slide 1420: Opened Excel workbook: Book1
# Slide 1421: Opened Excel workbook: Book1
# Slide 1422: Opened Excel workbook: Book1
# Slide 1423: Opened Excel workbook: Book1
# Slide 1424: Opened Excel workbook: Book1
# Slide 1425: Opened Excel workbook: Book1
# Slide 1426: Opened Excel workbook: Book1
# Slide 1427: Opened Excel workbook: Book1
# Slide 1428: Opened Excel workbook: Book1
# Slide 1429: Opened Excel workbook: Book1
# Slide 1430: Opened Excel workbook: Book1
# Slide 1431: Opened Excel workbook: Book1
# Slide 1432: Opened Excel workbook: Book1
# Slide 1433: Opened Excel workbook: Book1
# Slide 1434: Opened Excel workbook: Book1
# Slide 1435: Opened Excel workbook: Book1
# Slide 1436: Opened Excel workbook: Book1
# Slide 1437: Opened Excel workbook: Book1
# Slide 1438: Opened Excel workbook: Book1
# Slide 1439: Opened Excel workbook: Book1
# Slide 1440: Opened Excel workbook: Book1
# Slide 1441: Opened Excel workbook: Book1
# Slide 1442: Opened Excel workbook: Book1
# Slide 1443: Opened Excel workbook: Book1
# Slide 1444: Opened Excel workbook: Book1
# Slide 1445: Opened Excel workbook: Book1
# Slide 1446: Opened Excel workbook: Book1
# Slide 1447: Opened Excel workbook: Book1
# Slide 1448: Opened Excel workbook: Book1
# Slide 1449: Opened Excel workbook: Book1
# Slide 1450: Opened Excel workbook: Book1
# Slide 1451: Opened Excel workbook: Book1
# Slide 1452: Opened Excel workbook: Book1
# Slide 1453: Opened Excel workbook: Book1
# Slide 1454: Opened Excel workbook: Book1
# Slide 1455: Opened Excel workbook: Book1
# Slide 1456: Opened Excel workbook: Book1
# Slide 1457: Opened Excel workbook: Book1
# Slide 1458: Opened Excel workbook: Book1
# Slide 1459: Opened Excel workbook: Book1
# Slide 1460: Opened Excel workbook: Book1
# Slide 1461: Opened Excel workbook: Book1
# Slide 1462: Opened Excel workbook: Book1
# Slide 1463: Opened Excel workbook: Book1
# Slide 1464: Opened Excel workbook: Book1
# Slide 1465: Opened Excel workbook: Book1
# Slide 1466: Opened Excel workbook: Book1
# Slide 1467: Opened Excel workbook: Book1
# Slide 1468: Opened Excel workbook: Book1
# Slide 1469: Opened Excel workbook: Book1
# Slide 1470: Opened Excel workbook: Book1
# Slide 1471: Opened Excel workbook: Book1
# Slide 1472: Opened Excel workbook: Book1
# Slide 1473: Opened Excel workbook: Book1
# Slide 1474: Opened Excel workbook: Book1
# Slide 1475: Opened Excel workbook: Book1
# Slide 1476: Opened Excel workbook: Book1
# Slide 1477: Opened Excel workbook: Book1
# Slide 1478: Opened Excel workbook: Book1
# Slide 1479: Opened Excel workbook: Book1
# Slide 1480: Opened Excel workbook: Book1
# Slide 1481: Opened Excel workbook: Book1
# Slide 1482: Opened Excel workbook: Book1
# Slide 1483: Opened Excel workbook: Book1
# Slide 1484: Opened Excel workbook: Book1
# Slide 1485: Opened Excel workbook: Book1
# Slide 1486: Opened Excel workbook: Book1
# Slide 1487: Opened Excel workbook: Book1
# Slide 1488: Opened Excel workbook: Book1
# Slide 1489: Opened Excel workbook: Book1
# Slide 1490: Opened Excel workbook: Book1
# Slide 1491: Opened Excel workbook: Book1
# Slide 1492: Opened Excel workbook: Book1
# Slide 1493: Opened Excel workbook: Book1
# Slide 1494: Opened Excel workbook: Book1
# Slide 1495: Opened Excel workbook: Book1
# Slide 1496: Opened Excel workbook: Book1
# Slide 1497: Opened Excel workbook: Book1
# Slide 1498: Opened Excel workbook: Book1
# Slide 1499: Opened Excel workbook: Book1
# Slide 1500: Opened Excel workbook: Book1
# Slide 1501: Opened Excel workbook: Book1
# Slide 1502: Opened Excel workbook: Book1
# Slide 1503: Opened Excel workbook: Book1
# Slide 1504: Opened Excel workbook: Book1
# Slide 1505: Opened Excel workbook: Book1
# Slide 1506: Opened Excel workbook: Book1
# Slide 1507: Opened Excel workbook: Book1
# Slide 1508: Opened Excel workbook: Book1
# Slide 1509: Opened Excel workbook: Book1
# Slide 1510: Opened Excel workbook: Book1
# Slide 1511: Opened Excel workbook: Book1
# Slide 1512: Opened Excel workbook: Book1
# Slide 1513: Opened Excel workbook: Book1
# Slide 1514: Opened Excel workbook: Book1
# Slide 1515: Opened Excel workbook: Book1
# Slide 1516: Opened Excel workbook: Book1
# Slide 1517: Opened Excel workbook: Book1
# Slide 1518: Opened Excel workbook: Book1
# Slide 1519: Opened Excel workbook: Book1
# Slide 1520: Opened Excel workbook: Book1
# Slide 1521: Opened Excel workbook: Book1
# Slide 1522: Opened Excel workbook: Book1
# Slide 1523: Opened Excel workbook: Book1
# Slide 1524: Opened Excel workbook: Book1
# Slide 1525: Opened Excel workbook: Book1
# Slide 1526: Opened Excel workbook: Book1
# Slide 1527: Opened Excel workbook: Book1
# Slide 1528: Opened Excel workbook: Book1
# Slide 1529: Opened Excel workbook: Book1
# Slide 1530: Opened Excel workbook: Book1
# Slide 1531: Opened Excel workbook: Book1
# Slide 1532: Opened Excel workbook: Book1
# Slide 1533: Opened Excel workbook: Book1
# Slide 1534: Opened Excel workbook: Book1
# Slide 1535: Opened Excel workbook: Book1
# Slide 1536: Opened Excel workbook: Book1
# Slide 1537: Opened Excel workbook: Book1
# Slide 1538: Opened Excel workbook: Book1
# Slide 1539: Opened Excel workbook: Book1
# Slide 1540: Opened Excel workbook: Book1
# Slide 1541: Opened Excel workbook: Book1
# Slide 1542: Opened Excel workbook: Book1
# Slide 1543: Opened Excel workbook: Book1
# Slide 1544: Opened Excel workbook: Book1
# Slide 1545: Opened Excel workbook: Book1
# Slide 1546: Opened Excel workbook: Book1
# Slide 1547: Opened Excel workbook: Book1
# Slide 1548: Opened Excel workbook: Book1
# Slide 1549: Opened Excel workbook: Book1
# Slide 1550: Opened Excel workbook: Book1
# Slide 1551: Opened Excel workbook: Book1
# Slide 1552: Opened Excel workbook: Book1
# Slide 1553: Opened Excel workbook: Book1
# Slide 1554: Opened Excel workbook: Book1
# Slide 1555: Opened Excel workbook: Book1
# Slide 1556: Opened Excel workbook: Book1
# Slide 1557: Opened Excel workbook: Book1
# Slide 1558: Opened Excel workbook: Book1
# Slide 1559: Opened Excel workbook: Book1
# Slide 1560: Opened Excel workbook: Book1
# Slide 1561: Opened Excel workbook: Book1
# Slide 1562: Opened Excel workbook: Book1
# Slide 1563: Opened Excel workbook: Book1
# Slide 1564: Opened Excel workbook: Book1
# Slide 1565: Opened Excel workbook: Book1
# Slide 1566: Opened Excel workbook: Book1
# Slide 1567: Opened Excel workbook: Book1
# Slide 1568: Opened Excel workbook: Book1
# Slide 1569: Opened Excel workbook: Book1
# Slide 1570: Opened Excel workbook: Book1
# Slide 1571: Opened Excel workbook: Book1
# Slide 1572: Opened Excel workbook: Book1
# Slide 1573: Opened Excel workbook: Book1
# Slide 1574: Opened Excel workbook: Book1
# Slide 1575: Opened Excel workbook: Book1
# Slide 1576: Opened Excel workbook: Book1
# Slide 1577: Opened Excel workbook: Book1
# Slide 1578: Opened Excel workbook: Book1
# Slide 1579: Opened Excel workbook: Book1
# Slide 1580: Opened Excel workbook: Book1
# Slide 1581: Opened Excel workbook: Book1
# Slide 1582: Opened Excel workbook: Book1
# Slide 1583: Opened Excel workbook: Book1
# Slide 1584: Opened Excel workbook: Book1
# Slide 1585: Opened Excel workbook: Book1
# Slide 1586: Opened Excel workbook: Book1
# Slide 1587: Opened Excel workbook: Book1
# Slide 1588: Opened Excel workbook: Book1
# Slide 1589: Opened Excel workbook: Book1
# Slide 1590: Opened Excel workbook: Book1
# Slide 1591: Opened Excel workbook: Book1
# Slide 1592: Opened Excel workbook: Book1
# Slide 1593: Opened Excel workbook: Book1
# Slide 1594: Opened Excel workbook: Book1
# Slide 1595: Opened Excel workbook: Book1
# Slide 1596: Opened Excel workbook: Book1
# Slide 1597: Opened Excel workbook: Book1
# Slide 1598: Opened Excel workbook: Book1
# Slide 1599: Opened Excel workbook: Book1
# Slide 1600: Opened Excel workbook: Book1
# Slide 1601: Opened Excel workbook: Book1
# Slide 1602: Opened Excel workbook: Book1
# Slide 1603: Opened Excel workbook: Book1
# Slide 1604: Opened Excel workbook: Book1
# Slide 1605: Opened Excel workbook: Book1
# Slide 1606: Opened Excel workbook: Book1
# Slide 1607: Opened Excel workbook: Book1
# Slide 1608: Opened Excel workbook: Book1
# Slide 1609: Opened Excel workbook: Book1
# Slide 1610: Opened Excel workbook: Book1
# Slide 1611: Opened Excel workbook: Book1
# Slide 1612: Opened Excel workbook: Book1
# Slide 1613: Opened Excel workbook: Book1
# Slide 1614: Opened Excel workbook: Book1
# Slide 1615: Opened Excel workbook: Book1
# Slide 1616: Opened Excel workbook: Book1
# Slide 1617: Opened Excel workbook: Book1
# Slide 1618: Opened Excel workbook: Book1
# Slide 1619: Opened Excel workbook: Book1
# Slide 1620: Opened Excel workbook: Book1
# Slide 1621: Opened Excel workbook: Book1
# Slide 1622: Opened Excel workbook: Book1
# Slide 1623: Opened Excel workbook: Book1
# Slide 1624: Opened Excel workbook: Book1
# Slide 1625: Opened Excel workbook: Book1
# Slide 1626: Opened Excel workbook: Book1
# Slide 1627: Opened Excel workbook: Book1
# Slide 1628: Opened Excel workbook: Book1
# Slide 1629: Opened Excel workbook: Book1
# Slide 1630: Opened Excel workbook: Book1
# Slide 1631: Opened Excel workbook: Book1
# Slide 1632: Opened Excel workbook: Book1
# Slide 1633: Opened Excel workbook: Book1
# Slide 1634: Opened Excel workbook: Book1
# Slide 1635: Opened Excel workbook: Book1
# Slide 1636: Opened Excel workbook: Book1
# Slide 1637: Opened Excel workbook: Book1
# Slide 1638: Opened Excel workbook: Book1
# Slide 1639: Opened Excel workbook: Book1
# Slide 1640: Opened Excel workbook: Book1
# Slide 1641: Opened Excel workbook: Book1
# Slide 1642: Opened Excel workbook: Book1
# Slide 1643: Opened Excel workbook: Book1
# Slide 1644: Opened Excel workbook: Book1
# Slide 1645: Opened Excel workbook: Book1
# Slide 1646: Opened Excel workbook: Book1
# Slide 1647: Opened Excel workbook: Book1
# Slide 1648: Opened Excel workbook: Book1
# Slide 1649: Opened Excel workbook: Book1
# Slide 1650: Opened Excel workbook: Book1
# Slide 1651: Opened Excel workbook: Book1
# Slide 1652: Opened Excel workbook: Book1
# Slide 1653: Opened Excel workbook: Book1
# Slide 1654: Opened Excel workbook: Book1
# Slide 1655: Opened Excel workbook: Book1
# Slide 1656: Opened Excel workbook: Book1
# Slide 1657: Opened Excel workbook: Book1
# Slide 1658: Opened Excel workbook: Book1
# Slide 1659: Opened Excel workbook: Book1
# Slide 1660: Opened Excel workbook: Book1
# Slide 1661: Opened Excel workbook: Book1
# Slide 1662: Opened Excel workbook: Book1
# Slide 1663: Opened Excel workbook: Book1
# Slide 1664: Opened Excel workbook: Book1
# Slide 1665: Opened Excel workbook: Book1
# Slide 1666: Opened Excel workbook: Book1
# Slide 1667: Opened Excel workbook: Book1
